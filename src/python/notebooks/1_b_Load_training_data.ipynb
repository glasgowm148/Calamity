# %%
import pandas as pd
import numpy as np
import json
import glob
import ast

# %% [markdown]
# # Load the training data
#
# - Tweets
#     - A `Ground Truth Set` of tweets.
# - Labels
# - Information Types
#
# TREC-IS provides multiple Twitter datasets collected from a range of past wildfire, earthquake, flood, typhoon/hurricane, bombing and shooting events. We have had human annotators manually label this data into 25 information types based on the information each tweet contains, such as 'contains location' or is a 'search and rescue request'.
#
# Each tweet is also assigned a ***priority* label**, that indicates how critical the information within that tweet is for a response officer to see.

# %% [markdown]
# ### Labels
# TRECIS-2018-2020A-labels.json
#
# ```json
# [
#   {
#     "eventID": "joplinTornado2011",
#     "eventName": "2011 Joplin Tornado",
#     "eventDescription": "The 2011 Joplin tornado was a catastrophic EF5-rated multiple-vortex tornado that struck Joplin, Missouri, late in the afternoon of Sunday, May 22, 2011. The user is a response officer in the Missouri command and control center responsible for impact to the state. <a href='https://en.wikipedia.org/wiki/2011_Joplin_tornado' target='_blank'>Wikipedia Page<a>",
#     "eventType": "Unknown",
#     "postID": "72676276212731904",
#     "postCategories": [
#       "Factoid",
#       "Hashtags",
#       "News"
#     ],
#     "postPriority": "Low"
#   },
#  ```

# %%
labels_df = pd.read_json("../../../data/raw/data/2020/2020-A/labels/TRECIS-2018-2020A-labels.json")

# %% [markdown]
# ### Topics
#
# For each incident, we have a stream of related tweets, collected using hashtags, keyword, user, and geolocation monitoring. Each incident/event is accompanied by a brief "topic statement" in the TREC style:
#
#
# TRECIS-2018-2020A.topics
# ```xml
# <top>
# <num>TRECIS-CTIT-H-Training-001</num>
# <dataset>fireColorado2012</dataset>
# <title>2012 Colorado wildfires</title>
# <type>wildfire</type>
# <url>https://en.wikipedia.org/wiki/2012_Colorado_wildfires</url>
# <narr> The Colorado wildfires were an unusually devastating series of fires
# in the US state of Colorado, which occurred throughout June, July, and
# August 2012.
# </narr>
# </top>
# ```
# - Load the event topics from `TRECIS-2020-A.topics`
# - Map the events to ids `event_ids{}`
#
# ```python
# {'athensEarthquake2019': 'TRECIS-CTIT-H-Test-035',
#  'baltimoreFloods2019': 'TRECIS-CTIT-H-Test-036',
# ```

# %%
event_ids = {}

with open("../../../data/raw/data/2020/2020-A/topics/TRECIS-2020-A.topics", "r") as in_file:
    topic_num = ""
    topic_id = ""
    
    for line in in_file:
        
        if line.strip() == "</top>":
            event_ids[topic_id] = topic_num
        
        if line.startswith("<num>"):
            topic_num = line.partition(">")[-1].partition("<")[0]
              
        if line.startswith("<dataset>"):
            topic_id = line.partition(">")[-1].partition("<")[0]

#event_ids

# %% [markdown]
# ### Information Types (Categories)
# TRECIS-2020-ITypes-Task1.json
#
# This loads the ontology file containing the `Information Types` to a pandas dataframe
#
# ```json
# "identifier": "TRECIS-ITR-H-Types-v4-T1",
# 	"description": "TREC-IS Incident Tweet Routing (High-Level) Information Types. Version four, Task 1, created for the 2020 edition of the track.",
# 	"informationTypes": [
# 		{
# 			"id": "Request-GoodsServices",
# 			"desc": "The user is asking for a particular service or physical good.",
# 			"level": "High-level",
# 			"intentType": "Request",
# 			"exampleLowLevelTypes": [
# 				"PsychiatricNeed",
# 				"Equipment",
# 				"ShelterNeeded",
# 				"Vehicles"
# 			]
# 		},
# ```

# %%
df = pd.read_json("../../../data/raw/data/2020/2020-A/types/TRECIS-2020-ITypes-Task1.json", orient='columns')
df_split = df.join(pd.DataFrame(df.pop('informationTypes').tolist()))
df_split.head()
# Out:
#                  identifier  \
# 0  TRECIS-ITR-H-Types-v4-T1
# 1  TRECIS-ITR-H-Types-v4-T1
# 2  TRECIS-ITR-H-Types-v4-T1
# 3  TRECIS-ITR-H-Types-v4-T1
# 4  TRECIS-ITR-H-Types-v4-T1
#
#                                          description  \
# 0  TREC-IS Incident Tweet Routing (High-Level) In...
# 1  TREC-IS Incident Tweet Routing (High-Level) In...
# 2  TREC-IS Incident Tweet Routing (High-Level) In...
# 3  TREC-IS Incident Tweet Routing (High-Level) In...
# 4  TREC-IS Incident Tweet Routing (High-Level) In...
#
#                           id  \
# 0      Request-GoodsServices
# 1    Request-SearchAndRescue
# 2  Request-InformationWanted
# 3     CallToAction-Volunteer
# 4     CallToAction-Donations
#
#                                                 desc       level  \
# 0  The user is asking for a particular service or...  High-level
# 1  The user is requesting a rescue (for themselve...  High-level
# 2                 The user is requesting information  High-level
# 3  The user is asking people to volunteer to help...  High-level
# 4    The user is asking people to donate goods/money  High-level
#
#      intentType                               exampleLowLevelTypes
# 0       Request  [PsychiatricNeed, Equipment, ShelterNeeded, Ve...
# 1       Request                          [SelfRescue, OtherRescue]
# 2       Request         [PersonsNews, MissingPersons, EventStatus]
# 3  CallToAction                                      [RegisterNow]
# 4  CallToAction     [DonateMoney, DonateGoods, PromoteFundRaising]

# %% [markdown]
# ## Annotated Data
#
# Read the responses for each assessor and append them to an array of assessor data

# %%
annotators_data = []

def read_annotations(in_f_path):
    l_annotators_data = []
    
    with open(in_f_path, "rb") as in_file:
        annotator_content = in_file.read().decode("latin-1")
        trecis_training = json.loads(annotator_content)
        l_annotators_data.append(trecis_training)
        
    return l_annotators_data

# Read 2018 training file
in_f_path = "../../../data/raw/data/2018/training/TRECIS-CTIT-H-Training.json"
annotators_data.extend(read_annotations(in_f_path))
        
# Read each assessor file
for in_f_path in glob.iglob("../../data/raw/data/2020/2020-A/labels/TRECIS-*.json"):
    annotators_data.extend(read_annotations(in_f_path))
    
# 2019 Labels
for in_f_path in glob.iglob("../../data/raw/data/2019A/2019ALabels/*assr*.json"):
    annotators_data.extend(read_annotations(in_f_path))

    
print("Annotations:", len(annotators_data))
#print(annotators_data)
# Out:
# Annotations: 1

# %% [markdown]
# ## Map the annotated tweets to our Dataset
#
# outputs
#
# **tweet_category_map**
#
# ```python
# {'Advice': [243413475681001473,
#   213689735082807296, ...
#   ```
# **tweet_id_to_priority**
#
# ```python
# [{'tweet_id': 243377845072715777, 'priority': 'Low'},
#  {'tweet_id': 243367720022855680, 'priority': 'Low'},
#  {'tweet_id': 245776676586389504, 'priority': 'Low'},
# ```
#
# **tweet_id_to_category**
# ```python
# {243413475681001473: 1,
#  213689735082807296: 1,
#  212221690904723458: 1,
# ```
#
#
# > This is where I'm currently stuck. Not finding matches between postID and tweet_id

# %%
tweet_to_category = []
tweet_id_to_priority = []


# category_df
for annotator in annotators_data:
    local_events = annotator["events"]
    #print(local_events)
    for event in local_events:
        #print(event)
        for tweet in event["tweets"]:
            #print(tweet)
            
            # Pull out categories from the tweet dictionary
            for category in tweet["categories"]:
                #print(category)
                tweet_to_category.append({
                    "tweet_id": np.int64(tweet["postID"]),
                    "category": category
                })
                
            # Pull out priority, of which there should be only one
            tweet_id_to_priority.append({
                "tweet_id": np.int64(tweet["postID"]),
                "priority": tweet["priority"]
            })

print("Tweet to Category Map:", len(tweet_to_category))
print("Tweet ID to Priority Map:", len(tweet_id_to_priority))

category_df = pd.DataFrame(tweet_to_category)

print("Tweets with Category:", category_df["tweet_id"].value_counts().index.shape[0])

# Export to CSV
category_df.to_csv("tweet_to_category.csv", index=False)

# categoryMap()
# Maps a list of tweetIDs associated with categories

tweet_category_map = {}
category_df = pd.read_csv("tweet_to_category.csv")

cat_update_map = {
    "ContinuingNews": "News",
    "PastNews": "ContextualInformation",
    "KnownAlready": "OriginalEvent",
    "SignificantEventChange": "NewSubEvent",
}

category_df["category"] = category_df["category"].apply(lambda x: cat_update_map.get(x, x))

for category, tweets in category_df.groupby("category"):
    tweet_category_map[category] = list(tweets["tweet_id"])
    
# Deleted in 2019
del(tweet_category_map["Unknown"])

# Get a count of the category labels
category_to_label = {c:i+1 for i, c in enumerate(tweet_category_map.keys())}

tweet_id_to_category = {}

for category, tweet_ids in tweet_category_map.items():
   
        
    for tweet_id in tweet_ids:
        tweet_id_to_category[np.int64(tweet_id)] = category_to_label[category]
        
#tweet_id_to_category
#tweet_category_map
#tweet_id_to_priority
# Out:
# Tweet to Category Map: 1335
# Tweet ID to Priority Map: 1335
# Tweets with Category: 1335

# %% [markdown]
# ### Map priority labels to numerical values
# > We can then use this to calculate the error against our run

# %%
priority_df = pd.DataFrame(tweet_id_to_priority)

priority_mapping = {
    "Critical" : 1,
    "High" : 0.75,
    "Medium" : 0.5,
    "Low" : 0.25,
    "Unknown" : 0,
}


# Inst
temp_merged_priorities = []

for tweet_id, group in priority_df.groupby("tweet_id"):
    priority_list = list(group["priority"])
    p_scores = [priority_mapping[p] for p in priority_list]
    temp_merged_priorities.append({
        "tweet_id": tweet_id,
        "priority": np.mean(p_scores),
    })
    

# We then place these results in a dataframe to make them easier to work with 
priority_df = pd.DataFrame(temp_merged_priorities)

priority_map = {row["tweet_id"]: row["priority"] for idx, row in priority_df.iterrows()}

# %%
# Instantiate a new DataFrame to hold the categorised_tweets
eid = pd.DataFrame.from_records([tweet_id_to_category])
eid = eid.transpose()
eid = eid.reset_index()
eid.columns = ['tweet_id', 'label_id']
eid
# Out:
#                 tweet_id  label_id
# 0     243413475681001473         1
# 1     213689735082807296         1
# 2     212221690904723458         1
# 3     217393586537377792         1
# 4     378071202931032064         1
# ...                  ...       ...
# 1304  275577667875659776        22
# 1305  275540019781963777        22
# 1306  275720542621941760        22
# 1307  275877501895573504        22
# 1308  275581753106780162        22
#
# [1309 rows x 2 columns]

# %%
tweet_to_category_priority_df = priority_df.join(category_df.set_index('tweet_id'), on='tweet_id')
tweet_to_category_id_priority_df = tweet_to_category_priority_df.join(eid.set_index('tweet_id'), on='tweet_id')

tweet_to_category_id_priority_df
# Out:
#                 tweet_id  priority               category  label_id
# 0     211281973870727170      0.25             Irrelevant      11.0
# 1     211557401231495171      0.50  FirstPartyObservation       8.0
# 2     211565974422425600      0.75       ServiceAvailable      19.0
# 3     211607187653533697      0.50                Weather      22.0
# 4     211654415503990784      0.50                   News      15.0
# ...                  ...       ...                    ...       ...
# 1330  396336012726525952      0.25                   News      15.0
# 1331  396336079856345088      0.25                   News      15.0
# 1332  396336243442589696      0.25                   News      15.0
# 1333  396336297968562176      0.25                Factoid       7.0
# 1334  396336394429562880      0.25                   News      15.0
#
# [1335 rows x 4 columns]

# %%
df = tweet_to_category_id_priority_df.join(df_split, on="label_id")

# %%
print("Labels:", sum([len(v) for v in tweet_category_map.values()]))
# Out:
# Labels: 1309

# %% [markdown]
# ## ID -> EventID
#
# Returns a map of events with all identified tweet IDs
#
# ```
# {'albertaFloods2013': [347686624563429376,
#   347766337344503808,
#   347783236191129600,
#   347793432514801664,
# ```

# %%
merged_df = pd.merge(df, labels_df, left_on = 'tweet_id', right_on = 'postID', how = 'inner')
merged_df
# Out:
#                tweet_id  priority          category  label_id  \
# 0    211565974422425600      0.75  ServiceAvailable      19.0
# 1    211654415503990784      0.50              News      15.0
# 2    211681309368655872      0.25              News      15.0
# 3    211685621125742592      0.25          Official      16.0
# 4    211877049147736064      0.25           Factoid       7.0
# ..                  ...       ...               ...       ...
# 938  396336012726525952      0.25              News      15.0
# 939  396336079856345088      0.25              News      15.0
# 940  396336243442589696      0.25              News      15.0
# 941  396336297968562176      0.25           Factoid       7.0
# 942  396336394429562880      0.25              News      15.0
#
#                    identifier  \
# 0    TRECIS-ITR-H-Types-v4-T1
# 1    TRECIS-ITR-H-Types-v4-T1
# 2    TRECIS-ITR-H-Types-v4-T1
# 3    TRECIS-ITR-H-Types-v4-T1
# 4    TRECIS-ITR-H-Types-v4-T1
# ..                        ...
# 938  TRECIS-ITR-H-Types-v4-T1
# 939  TRECIS-ITR-H-Types-v4-T1
# 940  TRECIS-ITR-H-Types-v4-T1
# 941  TRECIS-ITR-H-Types-v4-T1
# 942  TRECIS-ITR-H-Types-v4-T1
#
#                                            description  \
# 0    TREC-IS Incident Tweet Routing (High-Level) In...
# 1    TREC-IS Incident Tweet Routing (High-Level) In...
# 2    TREC-IS Incident Tweet Routing (High-Level) In...
# 3    TREC-IS Incident Tweet Routing (High-Level) In...
# 4    TREC-IS Incident Tweet Routing (High-Level) In...
# ..                                                 ...
# 938  TREC-IS Incident Tweet Routing (High-Level) In...
# 939  TREC-IS Incident Tweet Routing (High-Level) In...
# 940  TREC-IS Incident Tweet Routing (High-Level) In...
# 941  TREC-IS Incident Tweet Routing (High-Level) In...
# 942  TREC-IS Incident Tweet Routing (High-Level) In...
#
#                                id  \
# 0            Report-OriginalEvent
# 1                 Report-Official
# 2                 Report-Official
# 3                     Report-News
# 4    Report-ThirdPartyObservation
# ..                            ...
# 938               Report-Official
# 939               Report-Official
# 940               Report-Official
# 941  Report-ThirdPartyObservation
# 942               Report-Official
#
#                                                   desc       level intentType  \
# 0    A report of the original event occuring. This ...  High-level     Report
# 1    An official report by a government or public s...  High-level     Report
# 2    An official report by a government or public s...  High-level     Report
# 3    The post is a news report providing/linking to...  High-level      Other
# 4    The user is reporting a information that they ...  High-level     Report
# ..                                                 ...         ...        ...
# 938  An official report by a government or public s...  High-level     Report
# 939  An official report by a government or public s...  High-level     Report
# 940  An official report by a government or public s...  High-level     Report
# 941  The user is reporting a information that they ...  High-level     Report
# 942  An official report by a government or public s...  High-level     Report
#
#                                   exampleLowLevelTypes                eventID  \
# 0                                                   []       fireColorado2012
# 1    [OfficialStatement, RegionalWarning, PublicAle...       fireColorado2012
# 2    [OfficialStatement, RegionalWarning, PublicAle...       fireColorado2012
# 3                          [NewsHeadline, NewsArticle]       fireColorado2012
# 4    [Group/IndividualMovement, PeopleEvacuating, D...       fireColorado2012
# ..                                                 ...                    ...
# 938  [OfficialStatement, RegionalWarning, PublicAle...  laAirportShooting2013
# 939  [OfficialStatement, RegionalWarning, PublicAle...  laAirportShooting2013
# 940  [OfficialStatement, RegionalWarning, PublicAle...  laAirportShooting2013
# 941  [Group/IndividualMovement, PeopleEvacuating, D...  laAirportShooting2013
# 942  [OfficialStatement, RegionalWarning, PublicAle...  laAirportShooting2013
#
#                                      eventName  \
# 0    DEMO: CrisisLex26 2012 Colorado wildfires
# 1    DEMO: CrisisLex26 2012 Colorado wildfires
# 2    DEMO: CrisisLex26 2012 Colorado wildfires
# 3    DEMO: CrisisLex26 2012 Colorado wildfires
# 4    DEMO: CrisisLex26 2012 Colorado wildfires
# ..                                         ...
# 938       CrisisLex26 2013 LA Airport Shooting
# 939       CrisisLex26 2013 LA Airport Shooting
# 940       CrisisLex26 2013 LA Airport Shooting
# 941       CrisisLex26 2013 LA Airport Shooting
# 942       CrisisLex26 2013 LA Airport Shooting
#
#                                       eventDescription eventType  \
# 0    The 2012 Colorado wildfires were an unusually ...   Unknown
# 1    The 2012 Colorado wildfires were an unusually ...   Unknown
# 2    The 2012 Colorado wildfires were an unusually ...   Unknown
# 3    The 2012 Colorado wildfires were an unusually ...   Unknown
# 4    The 2012 Colorado wildfires were an unusually ...   Unknown
# ..                                                 ...       ...
# 938  On November 1, 2013, a shooting occurred at ar...   Unknown
# 939  On November 1, 2013, a shooting occurred at ar...   Unknown
# 940  On November 1, 2013, a shooting occurred at ar...   Unknown
# 941  On November 1, 2013, a shooting occurred at ar...   Unknown
# 942  On November 1, 2013, a shooting occurred at ar...   Unknown
#
#                  postID      postCategories postPriority
# 0    211565974422425600  [ServiceAvailable]         High
# 1    211654415503990784              [News]       Medium
# 678  TRECIS-ITR-H-Types-v4-T1
# 713  TRECIS-ITR-H-Types-v4-T1
# 715  TRECIS-ITR-H-Types-v4-T1
# 717  TRECIS-ITR-H-Types-v4-T1
# 741  TRECIS-ITR-H-Types-v4-T1
# 779  TRECIS-ITR-H-Types-v4-T1
# 787  TRECIS-ITR-H-Types-v4-T1
# 796  TRECIS-ITR-H-Types-v4-T1
#
#                                            description  \
# 46   TREC-IS Incident Tweet Routing (High-Level) In...
# 78   TREC-IS Incident Tweet Routing (High-Level) In...
# 203  TREC-IS Incident Tweet Routing (High-Level) In...
# 207  TREC-IS Incident Tweet Routing (High-Level) In...
# 430  TREC-IS Incident Tweet Routing (High-Level) In...
# 439  TREC-IS Incident Tweet Routing (High-Level) In...
# 445  TREC-IS Incident Tweet Routing (High-Level) In...
# 457  TREC-IS Incident Tweet Routing (High-Level) In...
# 462  TREC-IS Incident Tweet Routing (High-Level) In...
# 478  TREC-IS Incident Tweet Routing (High-Level) In...
# 487  TREC-IS Incident Tweet Routing (High-Level) In...
# 488  TREC-IS Incident Tweet Routing (High-Level) In...
# 496  TREC-IS Incident Tweet Routing (High-Level) In...
# 511  TREC-IS Incident Tweet Routing (High-Level) In...
# 517  TREC-IS Incident Tweet Routing (High-Level) In...
# 589  TREC-IS Incident Tweet Routing (High-Level) In...
# 630  TREC-IS Incident Tweet Routing (High-Level) In...
# 667  TREC-IS Incident Tweet Routing (High-Level) In...
# 668  TREC-IS Incident Tweet Routing (High-Level) In...
# 674  TREC-IS Incident Tweet Routing (High-Level) In...
# 678  TREC-IS Incident Tweet Routing (High-Level) In...
# 713  TREC-IS Incident Tweet Routing (High-Level) In...
# 715  TREC-IS Incident Tweet Routing (High-Level) In...
# 717  TREC-IS Incident Tweet Routing (High-Level) In...
# 741  TREC-IS Incident Tweet Routing (High-Level) In...
# 779  TREC-IS Incident Tweet Routing (High-Level) In...
# 787  TREC-IS Incident Tweet Routing (High-Level) In...
# 796  TREC-IS Incident Tweet Routing (High-Level) In...
#
#                                id                                       desc  \
# 46   Report-FirstPartyObservation  The user is giving an eye-witness account
# 78   Report-FirstPartyObservation  The user is giving an eye-witness account
# 203  Report-FirstPartyObservation  The user is giving an eye-witness account
# 207  Report-FirstPartyObservation  The user is giving an eye-witness account
# 430  Report-FirstPartyObservation  The user is giving an eye-witness account
# 439  Report-FirstPartyObservation  The user is giving an eye-witness account
# 445  Report-FirstPartyObservation  The user is giving an eye-witness account
# 457  Report-FirstPartyObservation  The user is giving an eye-witness account
# 462  Report-FirstPartyObservation  The user is giving an eye-witness account
# 478  Report-FirstPartyObservation  The user is giving an eye-witness account
# 487  Report-FirstPartyObservation  The user is giving an eye-witness account
# 488  Report-FirstPartyObservation  The user is giving an eye-witness account
# 496  Report-FirstPartyObservation  The user is giving an eye-witness account
# 511  Report-FirstPartyObservation  The user is giving an eye-witness account
# 517  Report-FirstPartyObservation  The user is giving an eye-witness account
# 589  Report-FirstPartyObservation  The user is giving an eye-witness account
# 630  Report-FirstPartyObservation  The user is giving an eye-witness account
# 667  Report-FirstPartyObservation  The user is giving an eye-witness account
# 668  Report-FirstPartyObservation  The user is giving an eye-witness account
# 674  Report-FirstPartyObservation  The user is giving an eye-witness account
# 678  Report-FirstPartyObservation  The user is giving an eye-witness account
# 713  Report-FirstPartyObservation  The user is giving an eye-witness account
# 715  Report-FirstPartyObservation  The user is giving an eye-witness account
# 717  Report-FirstPartyObservation  The user is giving an eye-witness account
# 741  Report-FirstPartyObservation  The user is giving an eye-witness account
# 779  Report-FirstPartyObservation  The user is giving an eye-witness account
# 787  Report-FirstPartyObservation  The user is giving an eye-witness account
# 796  Report-FirstPartyObservation  The user is giving an eye-witness account
#
#           level intentType                               exampleLowLevelTypes  \
# 46   High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 78   High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 203  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 207  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 430  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 439  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 445  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 457  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 462  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 478  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 487  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 488  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 496  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 511  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 517  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 589  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 630  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 667  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 668  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 674  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 678  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 713  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 715  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 717  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 741  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 779  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 787  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
# 796  High-level     Report  [Group/IndividualMovement, PeopleEvacuating, D...
#
#                      eventID                                  eventName  \
# 46          fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# 78          fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# 203  costaRicaEarthquake2012     CrisisLex26 2012 Costa Rica Earthquake
# 717  The 2013 Colorado floods was a natural disaste...   Unknown
# 741  The 2013 Colorado floods was a natural disaste...   Unknown
# 779  The 2013 Colorado floods was a natural disaste...   Unknown
# 787  The 2013 Colorado floods was a natural disaste...   Unknown
# 796  The 2013 Colorado floods was a natural disaste...   Unknown
#
#                  postID     postCategories postPriority
# 46   212678790353137664  [EmergingThreats]         High
# 78   214012344139911168  [EmergingThreats]         High
# 203  243375546594119680  [EmergingThreats]         High
# 207  243376377057902592  [EmergingThreats]     Critical
# 430  275730885792378880  [EmergingThreats]         High
# 439  275753656660414464  [EmergingThreats]         High
# 445  275760120070279168  [EmergingThreats]         High
# 457  275784077943123968  [EmergingThreats]         High
# 462  275797919137939456  [EmergingThreats]         High
# 478  275855943164649472  [EmergingThreats]         High
# 487  275866034655858688  [EmergingThreats]         High
# 488  275866043023519744  [EmergingThreats]         High
# 496  275889229165391872  [EmergingThreats]         High
# 511  324702723675144192  [EmergingThreats]     Critical
# 517  324709166121877504  [EmergingThreats]     Critical
# 589  324738937295863808  [EmergingThreats]         High
# 630  378046271996440576  [EmergingThreats]         High
# 667  378139846935457792  [EmergingThreats]         High
# 668  378141524623912960  [EmergingThreats]         High
# 674  378158079579127808  [EmergingThreats]     Critical
# 678  378170578588291072  [EmergingThreats]         High
# 713  378219136033112064  [EmergingThreats]         High
# 715  378220553699463168  [EmergingThreats]     Critical
# 717  378221870731890688  [EmergingThreats]         High
# 741  379228499505995776  [EmergingThreats]         High
# 779  379361337278988288  [EmergingThreats]         High
# 787  379370682217271296  [EmergingThreats]         High
# 796  379387966948257792  [EmergingThreats]         High

# %%
df = df.drop(['postPriority',
              'eventName','eventType','eventDescription','eventID',
              'identifier',
              'description','category',
              'id','desc','postID','postCategories',
              'level',
              'exampleLowLevelTypes',
              'intentType'],axis =1)

df
# Out:
#                tweet_id  priority  label_id
# 0    211565974422425600      0.75      19.0
# 1    211654415503990784      0.50      15.0
# 2    211681309368655872      0.25      15.0
# 3    211685621125742592      0.25      16.0
# 4    211877049147736064      0.25       7.0
# ..                  ...       ...       ...
# 938  396336012726525952      0.25      15.0
# 939  396336079856345088      0.25      15.0
# 940  396336243442589696      0.25      15.0
# 941  396336297968562176      0.25       7.0
# 942  396336394429562880      0.25      15.0
#
# [943 rows x 3 columns]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    df.astype(int)
    return df[indices_to_keep].astype(np.float64)

# %% [markdown]
# ## Export to CSV

# %%
clean_dataset(df)
# Export to CSV
#merged_df.to_csv("train.csv", index=False)
df.to_csv("train.csv", index=False)
df = pd.read_csv("train.csv")
df
# Out:
#                tweet_id  priority  label_id
# 0    211565974422425600      0.75      19.0
# 1    211654415503990784      0.50      15.0
# 2    211681309368655872      0.25      15.0
# 3    211685621125742592      0.25      16.0
# 4    211877049147736064      0.25       7.0
# ..                  ...       ...       ...
# 917  396336012726525952      0.25      15.0
# 918  396336079856345088      0.25      15.0
# 919  396336243442589696      0.25      15.0
# 920  396336297968562176      0.25       7.0
# 921  396336394429562880      0.25      15.0
#
# [922 rows x 3 columns]
