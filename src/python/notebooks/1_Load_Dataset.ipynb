# %% [markdown]
# # Load the training data
#
# - Tweets
#     - A `Ground Truth Set` of tweets.
# - Labels
#     - `TRECIS-2018-2020A.topics`
# - Information Types
#     - `TRECIS-2020-ITypes-Task1.json`
#
# > TREC-IS provides multiple Twitter datasets collected from a range of past wildfire, earthquake, flood, typhoon/hurricane, bombing and shooting events. Human annotators manually label this data into 25 information types based on the information each tweet contains, such as 'contains location' or is a 'search and rescue request'.
#
# Each tweet is also assigned a ***priority* label**, that indicates how critical the information within that tweet is for a response officer to see.

# %%
import pandas as pd
import numpy as np
import json
import glob
import ast

# %% [markdown]
# # Information Types
# ``TRECIS-2020-ITypes-Task1.json``
#
# This loads the ontology file containing the **25** `Information Types` that we need to assign to the unlabelled tweets

# %%
df = pd.read_json("../../../data/raw/data/2020/2020-A/types/TRECIS-2020-ITypes-Task1.json", orient='columns')
df_split = df.join(pd.DataFrame(df.pop('informationTypes').tolist()))
informationTypes = df_split.drop(['identifier','description','level'],axis =1) # drop irrelevant (level?)
# Export to CSV
informationTypes.to_csv("dataset_information_types.csv", index=False)
informationTypes.head()
# Out:
#                           id  \
# 0      Request-GoodsServices
# 1    Request-SearchAndRescue
# 2  Request-InformationWanted
# 3     CallToAction-Volunteer
# 4     CallToAction-Donations
#
#                                                 desc    intentType  \
# 0  The user is asking for a particular service or...       Request
# 1  The user is requesting a rescue (for themselve...       Request
# 2                 The user is requesting information       Request
# 3  The user is asking people to volunteer to help...  CallToAction
# 4    The user is asking people to donate goods/money  CallToAction
#
#                                 exampleLowLevelTypes
# 0  [PsychiatricNeed, Equipment, ShelterNeeded, Ve...
# 1                          [SelfRescue, OtherRescue]
# 2         [PersonsNews, MissingPersons, EventStatus]
# 3                                      [RegisterNow]
# 4     [DonateMoney, DonateGoods, PromoteFundRaising]

# %% [markdown]
# # Topic Statements
#
# For each incident, we have a stream of related tweets, collected using hashtags, keyword, user, and geolocation monitoring. Each incident/event is accompanied by a brief "topic statement" in the TREC style:
#
#
# `TRECIS-2018-2020A.topics`
#
# ```xml
# <top>
# <num>TRECIS-CTIT-H-Training-001</num>
# <dataset>fireColorado2012</dataset>
# <title>2012 Colorado wildfires</title>
# <type>wildfire</type>
# <url>https://en.wikipedia.org/wiki/2012_Colorado_wildfires</url>
# <narr> The Colorado wildfires were an unusually devastating series of fires
# in the US state of Colorado, which occurred throughout June, July, and
# August 2012.
# </narr>
# </top>
# ```
#
#
#  -> `topic_ids`
# ```python
# {'athensEarthquake2019': 'TRECIS-CTIT-H-Test-035',
#  'baltimoreFloods2019': 'TRECIS-CTIT-H-Test-036',
# ```

# %%
topic_ids = {}

with open("../../../data/raw/data/2020/2020-A/topics/TRECIS-2020-A.topics", "r") as in_file:
    topic_num = ""
    topic_id = ""
    
    for line in in_file:
        
        if line.strip() == "</top>":
            topic_ids[topic_id] = topic_num
        
        if line.startswith("<num>"):
            topic_num = line.partition(">")[-1].partition("<")[0]
              
        if line.startswith("<dataset>"):
            topic_id = line.partition(">")[-1].partition("<")[0]

#topic_ids

# %% [markdown]
# # Labels
# `TRECIS-2018-2020A-labels.json` -> `labels_df`
#
# ```json
# [
#   {
#     "eventID": "joplinTornado2011",
#     "eventName": "2011 Joplin Tornado",
#     "eventDescription": "The 2011 Joplin tornado was a catastrophic EF5-rated multiple-vortex tornado that struck Joplin, Missouri, late in the afternoon of Sunday, May 22, 2011. The user is a response officer in the Missouri command and control center responsible for impact to the state. <a href='https://en.wikipedia.org/wiki/2011_Joplin_tornado' target='_blank'>Wikipedia Page<a>",
#     "eventType": "Unknown",
#     "postID": "72676276212731904",
#     "postCategories": [
#       "Factoid",
#       "Hashtags",
#       "News"
#     ],
#     "postPriority": "Low"
#   },
#  ```

# %%
labels_df = pd.read_json("../../../data/raw/data/2020/2020-A/labels/TRECIS-2018-2020A-labels.json")
labels_df.head()
# Out:
#              eventID            eventName  \
# 0  joplinTornado2011  2011 Joplin Tornado
# 1  joplinTornado2011  2011 Joplin Tornado
# 2  joplinTornado2011  2011 Joplin Tornado
# 3  joplinTornado2011  2011 Joplin Tornado
# 4  joplinTornado2011  2011 Joplin Tornado
#
#                                     eventDescription eventType  \
# 0  The 2011 Joplin tornado was a catastrophic EF5...   Unknown
# 1  The 2011 Joplin tornado was a catastrophic EF5...   Unknown
# 2  The 2011 Joplin tornado was a catastrophic EF5...   Unknown
# 3  The 2011 Joplin tornado was a catastrophic EF5...   Unknown
# 4  The 2011 Joplin tornado was a catastrophic EF5...   Unknown
#
#               postID                                 postCategories  \
# 0  72676276212731904                      [Factoid, Hashtags, News]
# 1  72678400833228800   [ServiceAvailable, Official, Hashtags, News]
# 2  72682396750848000                        [Sentiment, Irrelevant]
# 3  72693931619528704        [ThirdPartyObservation, Hashtags, News]
# 4  72698562223407104  [ThirdPartyObservation, Hashtags, Irrelevant]
#
#   postPriority
# 0          Low
# 1     Critical
# 2          Low
# 3       Medium
# 4          Low

# %% [markdown]
# ## Ground Truth
#
# `TRECIS2020A-t12-assr*.json`
#
# Read the responses for each assessor and append them to an array of assessor data
#
#
# ```json
# "events": [
# {"eventid": "siberianWildfires2020",
# "tweets": [
# {
#   "postID" : "1157446798564306945",
#   "timestamp" : "3 Mar 2020 12:28:12 GMT",
#   "categories" : [ "Irrelevant" ],
#   "indicatorTerms" : [ ],
#   "priority" : "Low",
#   "text" : "Trump offers Vladimir Putin help fighting forest fires in Siberia. (When California was consumed in biblical flames, Trump blamed the state's firefighters and slashed federal funding to stop wildfires.) https://t.co/TKTw3d0NLS"
# },
# ```

# %%
training_data = []

def read_annotations(in_f_path):
    l_training_data = []
    
    with open(in_f_path, "rb") as in_file:
        annotator_content = in_file.read().decode("latin-1")
        trecis_training = json.loads(annotator_content)
        l_training_data.append(trecis_training)
        
    return l_training_data

# Read 2018 training file
in_f_path = "../../../data/raw/data/2018/training/TRECIS-CTIT-H-Training.json"
training_data.extend(read_annotations(in_f_path))
        
# Read each assessor file
for in_f_path in glob.iglob("../../data/raw/data/2020/2020-A/labels/TRECIS-*.json"):
    training_data.extend(read_annotations(in_f_path))
    
# 2019 Labels
for in_f_path in glob.iglob("../../data/raw/data/2019A/2019ALabels/*assr*.json"):
    training_data.extend(read_annotations(in_f_path))

    
print("Annotations:", len(training_data))
#print(training_data)
# Out:
# Annotations: 1

# %% [markdown]
# ## Map the annotated tweets
#
# outputs
#
# **tweet_category_map**
#
# ```python
# {'Advice': [243413475681001473,
#   213689735082807296, ...
#   ```
# **tweet_id_to_priority**
#
# ```python
# [{'tweet_id': 243377845072715777, 'priority': 'Low'},
#  {'tweet_id': 243367720022855680, 'priority': 'Low'},
#  {'tweet_id': 245776676586389504, 'priority': 'Low'},
# ```
#
# **tweet_id_to_category**
# ```python
# {243413475681001473: 1,
#  213689735082807296: 1,
#  212221690904723458: 1,
# ```

# %%
tweet_to_category = []
tweet_id_to_priority = []

# tweet_to_category -> df[tweet_to_category] -> category_df -> tweet_category_map[for cat in category_df]

# category_df
for annotator in training_data:
    local_events = annotator["events"]
    for event in local_events:
        for tweet in event["tweets"]:
            # Pull out categories from the tweet dictionary
            for category in tweet["categories"]:
                #print(category)
                tweet_to_category.append({
                    # KnownAlready Official KnownAlready KnownAlready Official KnownAlready KnownAlready ContinuingNews ContinuingNews
                    "tweet_id": np.int64(tweet["postID"]),
                    "category": category
                })
                
            # Pull out priority, of which there should be only one
            tweet_id_to_priority.append({
                "tweet_id": np.int64(tweet["postID"]),
                "priority": tweet["priority"]
            })

print("Tweet to Category Map:", len(tweet_to_category))
print("Tweet ID to Priority Map:", len(tweet_id_to_priority))

category_df = pd.DataFrame(tweet_to_category)

print("Tweets with Category:", category_df["tweet_id"].value_counts().index.shape[0])

# Export to CSV
category_df.to_csv("tweet_to_category.csv", index=False)
tweet_to_category
# Out:
# Tweet to Category Map: 1335
# Tweet ID to Priority Map: 1335
# Tweets with Category: 1335
# [{'tweet_id': 243377845072715777, 'category': 'KnownAlready'},
#  {'tweet_id': 243367720022855680, 'category': 'KnownAlready'},
#  {'tweet_id': 245776676586389504, 'category': 'KnownAlready'},
#  {'tweet_id': 247293697593597952, 'category': 'KnownAlready'},
#  {'tweet_id': 243426079547723776, 'category': 'KnownAlready'},
#  {'tweet_id': 243401194737901569, 'category': 'Official'},
#  {'tweet_id': 243436699517071360, 'category': 'KnownAlready'},
#  {'tweet_id': 243366331687256065, 'category': 'KnownAlready'},
#  {'tweet_id': 243378847502962688, 'category': 'Official'},
#  {'tweet_id': 243375215244095488, 'category': 'KnownAlready'},
#  {'tweet_id': 243374590288592896, 'category': 'KnownAlready'},
#  {'tweet_id': 243461806629203969, 'category': 'ContinuingNews'},
#  {'tweet_id': 243394697765199872, 'category': 'ContinuingNews'},
#  {'tweet_id': 243411898605907968, 'category': 'Factoid'},
#  {'tweet_id': 243372316963254273, 'category': 'MovePeople'},
#  {'tweet_id': 243478046978473986, 'category': 'KnownAlready'},
#  {'tweet_id': 243427237188210688, 'category': 'Factoid'},
#  {'tweet_id': 243361759912681472, 'category': 'KnownAlready'},
#  {'tweet_id': 243366767903264768, 'category': 'Official'},
#  {'tweet_id': 243426675155685377, 'category': 'ContinuingNews'},
#  {'tweet_id': 243390360884232192, 'category': 'Official'},
#  {'tweet_id': 245851830112907264, 'category': 'Official'},
#  {'tweet_id': 243383729668640768, 'category': 'KnownAlready'},
#  {'tweet_id': 243368793773068289, 'category': 'Irrelevant'},
#  {'tweet_id': 245775888027877377, 'category': 'KnownAlready'},
#  {'tweet_id': 243455976546656256, 'category': 'ContinuingNews'},
#  {'tweet_id': 243375571747360768, 'category': 'SignificantEventChange'},
#  {'tweet_id': 243506920592392192, 'category': 'KnownAlready'},
#  {'tweet_id': 243399592530563073, 'category': 'Irrelevant'},
#  {'tweet_id': 243972182135431168, 'category': 'Irrelevant'},
#  {'tweet_id': 243532572930498560, 'category': 'ContinuingNews'},
#  {'tweet_id': 243384174285844480, 'category': 'KnownAlready'},
#  {'tweet_id': 243387449999515651, 'category': 'KnownAlready'},
#  {'tweet_id': 243388049797574657, 'category': 'KnownAlready'},
#  {'tweet_id': 243367116034670592, 'category': 'SignificantEventChange'},
#  {'tweet_id': 243361298518249473, 'category': 'KnownAlready'},
#  {'tweet_id': 243408136311029760, 'category': 'Sentiment'},
#  {'tweet_id': 243380223213711360, 'category': 'KnownAlready'},
#  {'tweet_id': 243365140496539651, 'category': 'KnownAlready'},
#  {'tweet_id': 243604408787681280, 'category': 'ContinuingNews'},
#  {'tweet_id': 243364461027659780, 'category': 'KnownAlready'},
#  {'tweet_id': 243363672506896384, 'category': 'Official'},
#  {'tweet_id': 243390792889163776, 'category': 'KnownAlready'},
#  {'tweet_id': 243967807463768064, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243368231706963969, 'category': 'KnownAlready'},
#  {'tweet_id': 243362783322861568, 'category': 'Official'},
#  {'tweet_id': 243377597612969984, 'category': 'Factoid'},
#  {'tweet_id': 243362997215571968, 'category': 'Official'},
#  {'tweet_id': 243683131692036096, 'category': 'ContinuingNews'},
#  {'tweet_id': 243626894459797504, 'category': 'Factoid'},
#  {'tweet_id': 243370475663806464, 'category': 'KnownAlready'},
#  {'tweet_id': 243377631142215680, 'category': 'KnownAlready'},
#  {'tweet_id': 243679361000153088, 'category': 'Irrelevant'},
#  {'tweet_id': 243374053396738049, 'category': 'KnownAlready'},
#  {'tweet_id': 243972773528084480, 'category': 'Irrelevant'},
#  {'tweet_id': 243363244704677888, 'category': 'KnownAlready'},
#  {'tweet_id': 243375504625905664, 'category': 'Official'},
#  {'tweet_id': 243372182737154048, 'category': 'ContinuingNews'},
#  {'tweet_id': 243368294621532160, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 243198739882332161, 'category': 'KnownAlready'},
#  {'tweet_id': 243375852753141760, 'category': 'Unknown'},
#  {'tweet_id': 243371905946615808, 'category': 'KnownAlready'},
#  {'tweet_id': 243379346616770560, 'category': 'ContinuingNews'},
#  {'tweet_id': 244410054885920768, 'category': 'SignificantEventChange'},
#  {'tweet_id': 243363487944937472, 'category': 'KnownAlready'},
#  {'tweet_id': 244243939484385280, 'category': 'Irrelevant'},
#  {'tweet_id': 243661325476167682, 'category': 'KnownAlready'},
#  {'tweet_id': 243398938219139072, 'category': 'KnownAlready'},
#  {'tweet_id': 243370001707458561, 'category': 'KnownAlready'},
#  {'tweet_id': 245294130270466048, 'category': 'Irrelevant'},
#  {'tweet_id': 243529741800468481, 'category': 'Irrelevant'},
#  {'tweet_id': 243389396185931776, 'category': 'KnownAlready'},
#  {'tweet_id': 243368005214552064, 'category': 'SignificantEventChange'},
#  {'tweet_id': 244104592135176192, 'category': 'Irrelevant'},
#  {'tweet_id': 243362288403369984, 'category': 'KnownAlready'},
#  {'tweet_id': 243203924050448384, 'category': 'KnownAlready'},
#  {'tweet_id': 243361642447007744, 'category': 'ContinuingNews'},
#  {'tweet_id': 243367229297676289, 'category': 'KnownAlready'},
#  {'tweet_id': 243365094396928001, 'category': 'KnownAlready'},
#  {'tweet_id': 243388116906426368, 'category': 'KnownAlready'},
#  {'tweet_id': 243419783897436161, 'category': 'SignificantEventChange'},
#  {'tweet_id': 243372774167552000, 'category': 'KnownAlready'},
#  {'tweet_id': 243968738607656960, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243967958454521856, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243437060227223552, 'category': 'KnownAlready'},
#  {'tweet_id': 243377807307190272, 'category': 'MultimediaShare'},
#  {'tweet_id': 244542703960989696, 'category': 'KnownAlready'},
#  {'tweet_id': 243364704293117952, 'category': 'KnownAlready'},
#  {'tweet_id': 243371897553817600, 'category': 'Irrelevant'},
#  {'tweet_id': 244571497836974080, 'category': 'Irrelevant'},
#  {'tweet_id': 243376377057902592, 'category': 'EmergingThreats'},
#  {'tweet_id': 243362649100931072, 'category': 'KnownAlready'},
#  {'tweet_id': 243384031645925376, 'category': 'Official'},
#  {'tweet_id': 243467544449662976, 'category': 'ServiceAvailable'},
#  {'tweet_id': 244127337828986880, 'category': 'PastNews'},
#  {'tweet_id': 243627842355744768, 'category': 'Discussion'},
#  {'tweet_id': 243979417314009088, 'category': 'Irrelevant'},
#  {'tweet_id': 243536058388733953, 'category': 'KnownAlready'},
#  {'tweet_id': 243969426469310464, 'category': 'Irrelevant'},
#  {'tweet_id': 243373579448754177, 'category': 'Official'},
#  {'tweet_id': 243431494389993472, 'category': 'KnownAlready'},
#  {'tweet_id': 243403535193096192, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 243396241285861376, 'category': 'KnownAlready'},
#  {'tweet_id': 243364184228757504, 'category': 'Official'},
#  {'tweet_id': 244541017854976000, 'category': 'Irrelevant'},
#  {'tweet_id': 243969803973455872, 'category': 'Irrelevant'},
#  {'tweet_id': 243375546594119680, 'category': 'EmergingThreats'},
#  {'tweet_id': 245830258786451456, 'category': 'Irrelevant'},
#  {'tweet_id': 243361697002299392, 'category': 'KnownAlready'},
#  {'tweet_id': 243556706976686080, 'category': 'Discussion'},
#  {'tweet_id': 243365824180662272, 'category': 'Sentiment'},
#  {'tweet_id': 243378377719955456, 'category': 'SignificantEventChange'},
#  {'tweet_id': 246582595318603779, 'category': 'Irrelevant'},
#  {'tweet_id': 243376792289828864, 'category': 'KnownAlready'},
#  {'tweet_id': 244452702589943808, 'category': 'Irrelevant'},
#  {'tweet_id': 243364263891189760, 'category': 'KnownAlready'},
#  {'tweet_id': 245138609697611776, 'category': 'Irrelevant'},
#  {'tweet_id': 243365371187429377, 'category': 'KnownAlready'},
#  {'tweet_id': 243409243628257280, 'category': 'Factoid'},
#  {'tweet_id': 243371620700401665, 'category': 'KnownAlready'},
#  {'tweet_id': 243368693072023552, 'category': 'Official'},
#  {'tweet_id': 243386724422672385, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243417254748893184, 'category': 'ContinuingNews'},
#  {'tweet_id': 243563099095973888, 'category': 'ContinuingNews'},
#  {'tweet_id': 243746071401078784, 'category': 'ContinuingNews'},
#  {'tweet_id': 243401379312459776, 'category': 'KnownAlready'},
#  {'tweet_id': 243370358244274176, 'category': 'KnownAlready'},
#  {'tweet_id': 243382043554234370, 'category': 'KnownAlready'},
#  {'tweet_id': 243709228634759169, 'category': 'Unknown'},
#  {'tweet_id': 243371243221426176, 'category': 'KnownAlready'},
#  {'tweet_id': 243404004917379073, 'category': 'KnownAlready'},
#  {'tweet_id': 243407440081739777, 'category': 'KnownAlready'},
#  {'tweet_id': 243968575038173184, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243366520439332865, 'category': 'KnownAlready'},
#  {'tweet_id': 243370110771945472, 'category': 'KnownAlready'},
#  {'tweet_id': 245689833522098177, 'category': 'ContinuingNews'},
#  {'tweet_id': 243373340386025473, 'category': 'Official'},
#  {'tweet_id': 243383784194580480, 'category': 'KnownAlready'},
#  {'tweet_id': 243478848094756864, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 245717721415831552, 'category': 'KnownAlready'},
#  {'tweet_id': 243365413155643393, 'category': 'KnownAlready'},
#  {'tweet_id': 243363055944232960, 'category': 'KnownAlready'},
#  {'tweet_id': 243433738351022080, 'category': 'Sentiment'},
#  {'tweet_id': 243435076325609474, 'category': 'KnownAlready'},
#  {'tweet_id': 243368961511677953, 'category': 'Official'},
#  {'tweet_id': 243377601790480384, 'category': 'Factoid'},
#  {'tweet_id': 243367120228974594, 'category': 'KnownAlready'},
#  {'tweet_id': 243383633216409600, 'category': 'KnownAlready'},
#  {'tweet_id': 243968616993808385, 'category': 'Irrelevant'},
#  {'tweet_id': 243970668000067585, 'category': 'Discussion'},
#  {'tweet_id': 243687825084653570, 'category': 'KnownAlready'},
#  {'tweet_id': 243430772973907969, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243394387386703872, 'category': 'Irrelevant'},
#  {'tweet_id': 243369246757904385, 'category': 'Official'},
#  {'tweet_id': 243377979273666560, 'category': 'Official'},
#  {'tweet_id': 243414822031589376, 'category': 'KnownAlready'},
#  {'tweet_id': 243382324589367296, 'category': 'Factoid'},
#  {'tweet_id': 243390297936130048, 'category': 'Official'},
#  {'tweet_id': 247215201198436352, 'category': 'KnownAlready'},
#  {'tweet_id': 243369351581925377, 'category': 'KnownAlready'},
#  {'tweet_id': 243969631977611265, 'category': 'Irrelevant'},
#  {'tweet_id': 243381598978981888, 'category': 'KnownAlready'},
#  {'tweet_id': 243373562663161856, 'category': 'KnownAlready'},
#  {'tweet_id': 243413102383755264, 'category': 'Sentiment'},
#  {'tweet_id': 243379824775819264, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 243413475681001473, 'category': 'Advice'},
#  {'tweet_id': 244420150596603904, 'category': 'Irrelevant'},
#  {'tweet_id': 243362053518131200, 'category': 'Official'},
#  {'tweet_id': 243365165695922176, 'category': 'KnownAlready'},
#  {'tweet_id': 243376779690123264, 'category': 'KnownAlready'},
#  {'tweet_id': 243372363088003072, 'category': 'ContinuingNews'},
#  {'tweet_id': 244557337858293760, 'category': 'KnownAlready'},
#  {'tweet_id': 243520291995791360, 'category': 'Irrelevant'},
#  {'tweet_id': 243585987387719680, 'category': 'KnownAlready'},
#  {'tweet_id': 243362175148773377, 'category': 'KnownAlready'},
#  {'tweet_id': 243449668338597889, 'category': 'Sentiment'},
#  {'tweet_id': 243363781554606080, 'category': 'Official'},
#  {'tweet_id': 243368013594779648, 'category': 'KnownAlready'},
#  {'tweet_id': 243397910606274560, 'category': 'Irrelevant'},
#  {'tweet_id': 243383138254999552, 'category': 'PastNews'},
#  {'tweet_id': 243389861741068288, 'category': 'KnownAlready'},
#  {'tweet_id': 243379438908219392, 'category': 'KnownAlready'},
#  {'tweet_id': 244556608070373377, 'category': 'KnownAlready'},
#  {'tweet_id': 244097768002568192, 'category': 'Irrelevant'},
#  {'tweet_id': 242997841134505985, 'category': 'KnownAlready'},
#  {'tweet_id': 243851088397234176, 'category': 'Unknown'},
#  {'tweet_id': 243371809460854784, 'category': 'KnownAlready'},
#  {'tweet_id': 244085394776391680, 'category': 'Irrelevant'},
#  {'tweet_id': 243384476254756864, 'category': 'ContinuingNews'},
#  {'tweet_id': 243425253286637568, 'category': 'Sentiment'},
#  {'tweet_id': 243391937929945088, 'category': 'KnownAlready'},
#  {'tweet_id': 243371213882261505, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 243367816496029696, 'category': 'KnownAlready'},
#  {'tweet_id': 243419578393321472, 'category': 'ContinuingNews'},
#  {'tweet_id': 243371167740747776, 'category': 'KnownAlready'},
#  {'tweet_id': 243385008943923200, 'category': 'KnownAlready'},
#  {'tweet_id': 243371989832695808, 'category': 'Official'},
#  {'tweet_id': 245779742605860864, 'category': 'KnownAlready'},
#  {'tweet_id': 243372056903815168, 'category': 'SignificantEventChange'},
#  {'tweet_id': 243970995164176386, 'category': 'Irrelevant'},
#  {'tweet_id': 243370001694871553, 'category': 'KnownAlready'},
#  {'tweet_id': 243615632724213760, 'category': 'KnownAlready'},
#  {'tweet_id': 243410216681619456, 'category': 'MultimediaShare'},
#  {'tweet_id': 243368676298993666, 'category': 'KnownAlready'},
#  {'tweet_id': 243491720426307584, 'category': 'ContinuingNews'},
#  {'tweet_id': 243365736121245697, 'category': 'SignificantEventChange'},
#  {'tweet_id': 245096918299066368, 'category': 'Irrelevant'},
#  {'tweet_id': 246060396052635649, 'category': 'Irrelevant'},
#  {'tweet_id': 244541726663000064, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 243875360817700864, 'category': 'Irrelevant'},
#  {'tweet_id': 243407784014643201, 'category': 'SignificantEventChange'},
#  {'tweet_id': 248156667257180160, 'category': 'KnownAlready'},
#  {'tweet_id': 243409293934723072, 'category': 'Factoid'},
#  {'tweet_id': 243363655750656001, 'category': 'InformationWanted'},
#  {'tweet_id': 243368881853431810, 'category': 'KnownAlready'},
#  {'tweet_id': 243443297190821888, 'category': 'KnownAlready'},
#  {'tweet_id': 243373805941182464, 'category': 'KnownAlready'},
#  {'tweet_id': 243370685391597568, 'category': 'KnownAlready'},
#  {'tweet_id': 243505574208237568, 'category': 'Unknown'},
#  {'tweet_id': 244544142607261697, 'category': 'KnownAlready'},
#  {'tweet_id': 243363907387928576, 'category': 'ContinuingNews'},
#  {'tweet_id': 244024363458895872, 'category': 'ContinuingNews'},
#  {'tweet_id': 244094269923676160, 'category': 'Irrelevant'},
#  {'tweet_id': 243381871591972865, 'category': 'Official'},
#  {'tweet_id': 243405867192561664, 'category': 'Irrelevant'},
#  {'tweet_id': 243445671158489089, 'category': 'KnownAlready'},
#  {'tweet_id': 243425169387970560, 'category': 'Irrelevant'},
#  {'tweet_id': 243682452202217473, 'category': 'ContinuingNews'},
#  {'tweet_id': 243369645195792384, 'category': 'Official'},
#  {'tweet_id': 246508091867295744, 'category': 'Irrelevant'},
#  {'tweet_id': 243377224290562048, 'category': 'KnownAlready'},
#  {'tweet_id': 245718686105759744, 'category': 'KnownAlready'},
#  {'tweet_id': 243376070861144064, 'category': 'Irrelevant'},
#  {'tweet_id': 243652869776089089, 'category': 'KnownAlready'},
#  {'tweet_id': 243397562474844160, 'category': 'Official'},
#  {'tweet_id': 243121539552256001, 'category': 'KnownAlready'},
#  {'tweet_id': 243496669692432384, 'category': 'Irrelevant'},
#  {'tweet_id': 243375861137539073, 'category': 'KnownAlready'},
#  {'tweet_id': 243381145994133504, 'category': 'Factoid'},
#  {'tweet_id': 243444878439231488, 'category': 'KnownAlready'},
#  {'tweet_id': 243373348787208193, 'category': 'KnownAlready'},
#  {'tweet_id': 243393980551811072, 'category': 'KnownAlready'},
#  {'tweet_id': 246604854460563456, 'category': 'ContinuingNews'},
#  {'tweet_id': 243363680916488192, 'category': 'KnownAlready'},
#  {'tweet_id': 243397809968140288, 'category': 'KnownAlready'},
#  {'tweet_id': 243369833931104256, 'category': 'ContinuingNews'},
#  {'tweet_id': 243922446086991872, 'category': 'KnownAlready'},
#  {'tweet_id': 212365530391252993, 'category': 'Factoid'},
#  {'tweet_id': 217744670753689603, 'category': 'MultimediaShare'},
#  {'tweet_id': 212311994286620672, 'category': 'MultimediaShare'},
#  {'tweet_id': 217030749856088066, 'category': 'Unknown'},
#  {'tweet_id': 217746356842926080, 'category': 'MultimediaShare'},
#  {'tweet_id': 213348184506908673, 'category': 'MovePeople'},
#  {'tweet_id': 217732012314861568, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 212970143511363587, 'category': 'Factoid'},
#  {'tweet_id': 216961334129078272, 'category': 'Discussion'},
#  {'tweet_id': 212552860590813184, 'category': 'MultimediaShare'},
#  {'tweet_id': 217273864303034369, 'category': 'Irrelevant'},
#  {'tweet_id': 212617469645438976, 'category': 'ContinuingNews'},
#  {'tweet_id': 217579473883762689, 'category': 'ContinuingNews'},
#  {'tweet_id': 211671247258521602, 'category': 'ContinuingNews'},
#  {'tweet_id': 211685621125742592, 'category': 'Official'},
#  {'tweet_id': 212590940664238080, 'category': 'Sentiment'},
#  {'tweet_id': 213047834579173377, 'category': 'MultimediaShare'},
#  {'tweet_id': 215127597007384578, 'category': 'Sentiment'},
#  {'tweet_id': 212306336183091200, 'category': 'ContinuingNews'},
#  {'tweet_id': 212824504689360896, 'category': 'ContinuingNews'},
#  {'tweet_id': 211654415503990784, 'category': 'ContinuingNews'},
#  {'tweet_id': 212632141304041473, 'category': 'Factoid'},
#  {'tweet_id': 217351928705847297, 'category': 'MultimediaShare'},
#  {'tweet_id': 216342460396343297, 'category': 'ContinuingNews'},
#  {'tweet_id': 214672162693451777, 'category': 'EmergingThreats'},
#  {'tweet_id': 216743465193713664, 'category': 'Irrelevant'},
#  {'tweet_id': 214044891943145472, 'category': 'Irrelevant'},
#  {'tweet_id': 211910322582335488, 'category': 'ServiceAvailable'},
#  {'tweet_id': 211281973870727170, 'category': 'Irrelevant'},
#  {'tweet_id': 212887096262791168, 'category': 'ContinuingNews'},
#  {'tweet_id': 217258538316210177, 'category': 'Sentiment'},
#  {'tweet_id': 217048223334932480, 'category': 'ContinuingNews'},
#  {'tweet_id': 216349737488621568, 'category': 'MultimediaShare'},
#  {'tweet_id': 212582216503533569, 'category': 'Discussion'},
#  {'tweet_id': 211732966416719873, 'category': 'ContinuingNews'},
#  {'tweet_id': 212670988956090371, 'category': 'Sentiment'},
#  {'tweet_id': 217074429367304194, 'category': 'Sentiment'},
#  {'tweet_id': 212023103197421569, 'category': 'ContinuingNews'},
#  {'tweet_id': 214829348434345986, 'category': 'ContinuingNews'},
#  {'tweet_id': 212337210442264576, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 212202460046049280, 'category': 'Factoid'},
#  {'tweet_id': 212046599696826369, 'category': 'MultimediaShare'},
#  {'tweet_id': 211968233312485378, 'category': 'MultimediaShare'},
#  {'tweet_id': 217733576786055168, 'category': 'MultimediaShare'},
#  {'tweet_id': 214164312175026177, 'category': 'ContinuingNews'},
#  {'tweet_id': 213597628162777088, 'category': 'ContinuingNews'},
#  {'tweet_id': 213003463032963072, 'category': 'ContinuingNews'},
#  {'tweet_id': 217745538941071361, 'category': 'Irrelevant'},
#  {'tweet_id': 212660335415529475, 'category': 'Discussion'},
#  {'tweet_id': 214713954734317569, 'category': 'EmergingThreats'},
#  {'tweet_id': 212700856590671874, 'category': 'Irrelevant'},
#  {'tweet_id': 215138435093110784, 'category': 'Donations'},
#  {'tweet_id': 213689735082807296, 'category': 'Advice'},
#  {'tweet_id': 216983274558464000, 'category': 'SignificantEventChange'},
#  {'tweet_id': 212169203422199808, 'category': 'Sentiment'},
#  {'tweet_id': 212559890248499200, 'category': 'Factoid'},
#  {'tweet_id': 217641411166740481, 'category': 'ContinuingNews'},
#  {'tweet_id': 213384297481113602, 'category': 'Factoid'},
#  {'tweet_id': 212221690904723458, 'category': 'Advice'},
#  {'tweet_id': 214949230027096064, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 213824988795518976, 'category': 'MultimediaShare'},
#  {'tweet_id': 215119355187445760, 'category': 'ContinuingNews'},
#  {'tweet_id': 214350006621192192, 'category': 'Irrelevant'},
#  {'tweet_id': 217481515918049280, 'category': 'Donations'},
#  {'tweet_id': 213627768435519488, 'category': 'Factoid'},
#  {'tweet_id': 212019143803797505, 'category': 'ContinuingNews'},
#  {'tweet_id': 215449295938265089, 'category': 'MultimediaShare'},
#  {'tweet_id': 214509692133703683, 'category': 'EmergingThreats'},
#  {'tweet_id': 212441208226717697, 'category': 'Irrelevant'},
#  {'tweet_id': 217707215602192384, 'category': 'Irrelevant'},
#  {'tweet_id': 212176367289253888, 'category': 'Sentiment'},
#  {'tweet_id': 217728396854177793, 'category': 'MultimediaShare'},
#  {'tweet_id': 212414263984275456, 'category': 'ContinuingNews'},
#  {'tweet_id': 215578157523275776, 'category': 'ContinuingNews'},
#  {'tweet_id': 212615137604018177, 'category': 'MovePeople'},
#  {'tweet_id': 217479968219873280, 'category': 'MultimediaShare'},
#  {'tweet_id': 212841818780467200, 'category': 'ContinuingNews'},
#  {'tweet_id': 217745157259395073, 'category': 'MultimediaShare'},
#  {'tweet_id': 215869691003011072, 'category': 'Donations'},
#  {'tweet_id': 216774209446215680, 'category': 'MovePeople'},
#  {'tweet_id': 217691780571856896, 'category': 'SignificantEventChange'},
#  {'tweet_id': 214131592413712385, 'category': 'ContinuingNews'},
#  {'tweet_id': 217720503148888065, 'category': 'ServiceAvailable'},
#  {'tweet_id': 213967951626383360, 'category': 'Factoid'},
#  {'tweet_id': 215174099247435776, 'category': 'Irrelevant'},
#  {'tweet_id': 214425449537867776, 'category': 'SignificantEventChange'},
#  {'tweet_id': 212298199229149184, 'category': 'ContinuingNews'},
#  {'tweet_id': 213391209673134080, 'category': 'Factoid'},
#  {'tweet_id': 216934155034963969, 'category': 'ContinuingNews'},
#  {'tweet_id': 213702829674741761, 'category': 'ServiceAvailable'},
#  {'tweet_id': 213295311106482178, 'category': 'ContinuingNews'},
#  {'tweet_id': 213470175830351872, 'category': 'ContinuingNews'},
#  {'tweet_id': 216941084033560577, 'category': 'Irrelevant'},
#  {'tweet_id': 216654818595450882, 'category': 'Irrelevant'},
#  {'tweet_id': 216749215613857792, 'category': 'Unknown'},
#  {'tweet_id': 213553466344341504, 'category': 'Factoid'},
#  {'tweet_id': 212000114246553600, 'category': 'MultimediaShare'},
#  {'tweet_id': 215011481916424193, 'category': 'Weather'},
#  {'tweet_id': 211565974422425600, 'category': 'ServiceAvailable'},
#  {'tweet_id': 214485545521385473, 'category': 'MultimediaShare'},
#  {'tweet_id': 217724286427860992, 'category': 'MultimediaShare'},
#  {'tweet_id': 216305818927251456, 'category': 'MovePeople'},
#  {'tweet_id': 215465313989427200, 'category': 'Factoid'},
#  {'tweet_id': 217352981446787072, 'category': 'Factoid'},
#  {'tweet_id': 214745932141563913, 'category': 'Official'},
#  {'tweet_id': 212158197543337984, 'category': 'Factoid'},
#  {'tweet_id': 217679969407602688, 'category': 'Sentiment'},
#  {'tweet_id': 217680296563326978, 'category': 'SignificantEventChange'},
#  {'tweet_id': 212228347286130689, 'category': 'Discussion'},
#  {'tweet_id': 216550187492057088, 'category': 'Donations'},
#  {'tweet_id': 215763893904089088, 'category': 'CleanUp'},
#  {'tweet_id': 212678790353137664, 'category': 'EmergingThreats'},
#  {'tweet_id': 215855174546231296, 'category': 'Weather'},
#  {'tweet_id': 211893016892424192, 'category': 'Factoid'},
#  {'tweet_id': 217744012214403074, 'category': 'Irrelevant'},
#  {'tweet_id': 212525333348491264, 'category': 'ContinuingNews'},
#  {'tweet_id': 211557401231495171, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 216900122443923456, 'category': 'ContinuingNews'},
#  {'tweet_id': 212002932818841602, 'category': 'Factoid'},
#  {'tweet_id': 217742238061563904, 'category': 'ContinuingNews'},
#  {'tweet_id': 216920003461648385, 'category': 'Donations'},
#  {'tweet_id': 217305728438902786, 'category': 'Factoid'},
#  {'tweet_id': 213015790109196288, 'category': 'MultimediaShare'},
#  {'tweet_id': 211971932697010178, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 217008167752699904, 'category': 'MultimediaShare'},
#  {'tweet_id': 212025686918049793, 'category': 'ContinuingNews'},
#  {'tweet_id': 216868350607884288, 'category': 'ContinuingNews'},
#  {'tweet_id': 216951989232349184, 'category': 'Weather'},
#  {'tweet_id': 212587354542706688, 'category': 'ContinuingNews'},
#  {'tweet_id': 212201952547840000, 'category': 'Irrelevant'},
#  {'tweet_id': 215023850889547776, 'category': 'Factoid'},
#  {'tweet_id': 212061829235613698, 'category': 'Irrelevant'},
#  {'tweet_id': 215317343130238976, 'category': 'ContinuingNews'},
#  {'tweet_id': 213662769889812482, 'category': 'Discussion'},
#  {'tweet_id': 216262361781248003, 'category': 'Donations'},
#  {'tweet_id': 213007598637678592, 'category': 'ContinuingNews'},
#  {'tweet_id': 213748442739118080, 'category': 'Donations'},
#  {'tweet_id': 214349314556821504, 'category': 'ContinuingNews'},
#  {'tweet_id': 211976521278164993, 'category': 'MultimediaShare'},
#  {'tweet_id': 213275195224494080, 'category': 'Donations'},
#  {'tweet_id': 216958289055977473, 'category': 'Sentiment'},
#  {'tweet_id': 213303712284811264, 'category': 'Official'},
#  {'tweet_id': 212937008484589570, 'category': 'Official'},
#  {'tweet_id': 214168795881811969, 'category': 'ContinuingNews'},
#  {'tweet_id': 217744897220943873, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 215352826958843904, 'category': 'Factoid'},
#  {'tweet_id': 211964198396231680, 'category': 'MovePeople'},
#  {'tweet_id': 212242750534451200, 'category': 'Volunteer'},
#  {'tweet_id': 212452734148939776, 'category': 'Factoid'},
#  {'tweet_id': 211884082991333376, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 213751626211667968, 'category': 'Factoid'},
#  {'tweet_id': 211877049147736064, 'category': 'Factoid'},
#  {'tweet_id': 216685898392276992, 'category': 'ServiceAvailable'},
#  {'tweet_id': 217101704905232385, 'category': 'Sentiment'},
#  {'tweet_id': 212032414564880384, 'category': 'MultimediaShare'},
#  {'tweet_id': 216984293770141696, 'category': 'SignificantEventChange'},
#  {'tweet_id': 213336062980915200, 'category': 'Official'},
#  {'tweet_id': 216979315110318080, 'category': 'Discussion'},
#  {'tweet_id': 213469647377408000, 'category': 'Factoid'},
#  {'tweet_id': 211681309368655872, 'category': 'ContinuingNews'},
#  {'tweet_id': 214826689233027072, 'category': 'ContinuingNews'},
#  {'tweet_id': 213416409043181568, 'category': 'ContinuingNews'},
#  {'tweet_id': 217276200555528192, 'category': 'MultimediaShare'},
#  {'tweet_id': 216366107873914880, 'category': 'MultimediaShare'},
#  {'tweet_id': 213002380910927874, 'category': 'ContinuingNews'},
#  {'tweet_id': 212319443383103488, 'category': 'Irrelevant'},
#  {'tweet_id': 211848238465159170, 'category': 'Official'},
#  {'tweet_id': 214194607657992192, 'category': 'Factoid'},
#  {'tweet_id': 211991952135172098, 'category': 'MultimediaShare'},
#  {'tweet_id': 213671603081457664, 'category': 'ContinuingNews'},
#  {'tweet_id': 217088622871060480, 'category': 'Irrelevant'},
#  {'tweet_id': 214722393673969665, 'category': 'Weather'},
#  {'tweet_id': 214479962911154176, 'category': 'Irrelevant'},
#  {'tweet_id': 211790625530593282, 'category': 'MovePeople'},
#  {'tweet_id': 212227898512388096, 'category': 'Sentiment'},
#  {'tweet_id': 212692916794163200, 'category': 'Discussion'},
#  {'tweet_id': 217019005830049793, 'category': 'ContinuingNews'},
#  {'tweet_id': 212617058616225792, 'category': 'MultimediaShare'},
#  {'tweet_id': 217420929200959488, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 216759722336980992, 'category': 'MultimediaShare'},
#  {'tweet_id': 211703656611979265, 'category': 'ContinuingNews'},
#  {'tweet_id': 212462741770862592, 'category': 'ContinuingNews'},
#  {'tweet_id': 216962340774617089, 'category': 'ContinuingNews'},
#  {'tweet_id': 215815987151376385, 'category': 'MultimediaShare'},
#  {'tweet_id': 214915876930068481, 'category': 'Factoid'},
#  {'tweet_id': 212659349779267584, 'category': 'Irrelevant'},
#  {'tweet_id': 212595864772952064, 'category': 'Irrelevant'},
#  {'tweet_id': 212384295719931904, 'category': 'Factoid'},
#  {'tweet_id': 217462574432780289, 'category': 'Factoid'},
#  {'tweet_id': 211964315853524993, 'category': 'MovePeople'},
#  {'tweet_id': 214385830171648000, 'category': 'Factoid'},
#  {'tweet_id': 212231669170716672, 'category': 'Sentiment'},
#  {'tweet_id': 215543047017074690, 'category': 'Irrelevant'},
#  {'tweet_id': 216336307352371200, 'category': 'MultimediaShare'},
#  {'tweet_id': 211607187653533697, 'category': 'Weather'},
#  {'tweet_id': 212099863171710976, 'category': 'ContinuingNews'},
#  {'tweet_id': 217429728829784064, 'category': 'MultimediaShare'},
#  {'tweet_id': 217393586537377792, 'category': 'Advice'},
#  {'tweet_id': 212539984052363265, 'category': 'ContinuingNews'},
#  {'tweet_id': 217409776542433281, 'category': 'MovePeople'},
#  {'tweet_id': 217663359955378177, 'category': 'Factoid'},
#  {'tweet_id': 214426300994162688, 'category': 'SignificantEventChange'},
#  {'tweet_id': 214226740220928000, 'category': 'ContinuingNews'},
#  {'tweet_id': 215821620097462272, 'category': 'Irrelevant'},
#  {'tweet_id': 216608731599872000, 'category': 'Irrelevant'},
#  {'tweet_id': 216199195542036481, 'category': 'ContinuingNews'},
#  {'tweet_id': 212315735609966592, 'category': 'Factoid'},
#  {'tweet_id': 213266525606526977, 'category': 'ContinuingNews'},
#  {'tweet_id': 213307550081359872, 'category': 'Irrelevant'},
#  {'tweet_id': 212604953846480896, 'category': 'Irrelevant'},
#  {'tweet_id': 212311709082337281, 'category': 'MultimediaShare'},
#  {'tweet_id': 216664859759214592, 'category': 'Hashtags'},
#  {'tweet_id': 212137133736075264, 'category': 'ContinuingNews'},
#  {'tweet_id': 212212127929344001, 'category': 'Official'},
#  {'tweet_id': 214917449777295365, 'category': 'ContinuingNews'},
#  {'tweet_id': 211931512180965378, 'category': 'Donations'},
#  {'tweet_id': 217458048770375681, 'category': 'Factoid'},
#  {'tweet_id': 212197095518633984, 'category': 'Discussion'},
#  {'tweet_id': 214570425664024576, 'category': 'MultimediaShare'},
#  {'tweet_id': 212373109477617664, 'category': 'Factoid'},
#  {'tweet_id': 212429443170435072, 'category': 'Unknown'},
#  {'tweet_id': 215079349928476673, 'category': 'Official'},
#  {'tweet_id': 212200052511342594, 'category': 'Factoid'},
#  {'tweet_id': 216650766893596672, 'category': 'Irrelevant'},
#  {'tweet_id': 213356292113305600, 'category': 'Weather'},
#  {'tweet_id': 213413158474358784, 'category': 'Sentiment'},
#  {'tweet_id': 214012344139911168, 'category': 'EmergingThreats'},
#  {'tweet_id': 212231891477217283, 'category': 'MultimediaShare'},
#  {'tweet_id': 217079399613337602, 'category': 'InformationWanted'},
#  {'tweet_id': 214794103693643776, 'category': 'Weather'},
#  {'tweet_id': 212377068904787969, 'category': 'ContinuingNews'},
#  {'tweet_id': 212552097219100673, 'category': 'MovePeople'},
#  {'tweet_id': 214182184104370176, 'category': 'ContinuingNews'},
#  {'tweet_id': 212679595655299072, 'category': 'ServiceAvailable'},
#  {'tweet_id': 217569856327909376, 'category': 'Factoid'},
#  {'tweet_id': 215806621253771266, 'category': 'Irrelevant'},
#  {'tweet_id': 212579779608719362, 'category': 'ContinuingNews'},
#  {'tweet_id': 217730775020343297, 'category': 'ServiceAvailable'},
#  {'tweet_id': 217634977108602880, 'category': 'Irrelevant'},
#  {'tweet_id': 212847581733208064, 'category': 'ContinuingNews'},
#  {'tweet_id': 215249416393719808, 'category': 'Donations'},
#  {'tweet_id': 212706464366727169, 'category': 'ContinuingNews'},
#  {'tweet_id': 216267445248331778, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 212364712506163201, 'category': 'Factoid'},
#  {'tweet_id': 211958091485417473, 'category': 'MovePeople'},
#  {'tweet_id': 214886101553397760, 'category': 'Factoid'},
#  {'tweet_id': 214850416427548672, 'category': 'ContinuingNews'},
#  {'tweet_id': 215062358802968576, 'category': 'MultimediaShare'},
#  {'tweet_id': 212214560617275392, 'category': 'Irrelevant'},
#  {'tweet_id': 214490071183802368, 'category': 'MultimediaShare'},
#  {'tweet_id': 217103105794375680, 'category': 'Irrelevant'},
#  {'tweet_id': 212185569588035585, 'category': 'Irrelevant'},
#  {'tweet_id': 214201167515885568, 'category': 'ContinuingNews'},
#  {'tweet_id': 212847162315382785, 'category': 'ContinuingNews'},
#  {'tweet_id': 217291211961147393, 'category': 'Unknown'},
#  {'tweet_id': 211830756614475777, 'category': 'Irrelevant'},
#  {'tweet_id': 212612847501455361, 'category': 'ContinuingNews'},
#  {'tweet_id': 213138934887223296, 'category': 'MultimediaShare'},
#  {'tweet_id': 213125177540739072, 'category': 'Irrelevant'},
#  {'tweet_id': 211904811250089984, 'category': 'SignificantEventChange'},
#  {'tweet_id': 217039595639029760, 'category': 'Sentiment'},
#  {'tweet_id': 213070509003374592, 'category': 'Factoid'},
#  {'tweet_id': 213373622943891457, 'category': 'Factoid'},
#  {'tweet_id': 379112698958446597, 'category': 'MultimediaShare'},
#  {'tweet_id': 378078203228585985, 'category': 'ContinuingNews'},
#  {'tweet_id': 378208105021976576, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 379361337278988288, 'category': 'EmergingThreats'},
#  {'tweet_id': 378112919499579392, 'category': 'ContinuingNews'},
#  {'tweet_id': 378109257842827264, 'category': 'Sentiment'},
#  {'tweet_id': 379356052493312000, 'category': 'Irrelevant'},
#  {'tweet_id': 378054652215824384, 'category': 'MovePeople'},
#  {'tweet_id': 379250678977159169, 'category': 'MultimediaShare'},
#  {'tweet_id': 379144416293695488, 'category': 'Factoid'},
#  {'tweet_id': 379271235269443586, 'category': 'Official'},
#  {'tweet_id': 378181332792115200, 'category': 'ContinuingNews'},
#  {'tweet_id': 378198479111073792, 'category': 'ContinuingNews'},
#  {'tweet_id': 379228814070407168, 'category': 'Irrelevant'},
#  {'tweet_id': 379110102663700480, 'category': 'Factoid'},
#  {'tweet_id': 379412612653387776, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 378150852793749504, 'category': 'Factoid'},
#  {'tweet_id': 378220914443157504, 'category': 'ServiceAvailable'},
#  {'tweet_id': 379140385554964480, 'category': 'Sentiment'},
#  {'tweet_id': 378217953256157185, 'category': 'Official'},
#  {'tweet_id': 378195434033782784, 'category': 'Sentiment'},
#  {'tweet_id': 378198986597093376, 'category': 'Factoid'},
#  {'tweet_id': 379229728420265985, 'category': 'ContinuingNews'},
#  {'tweet_id': 378122033697402880, 'category': 'MultimediaShare'},
#  {'tweet_id': 378071202931032064, 'category': 'Advice'},
#  {'tweet_id': 378105671729684482, 'category': 'ContinuingNews'},
#  {'tweet_id': 378212785886224384, 'category': 'MultimediaShare'},
#  {'tweet_id': 379425505973256192, 'category': 'ContinuingNews'},
#  {'tweet_id': 379157749990719488, 'category': 'KnownAlready'},
#  {'tweet_id': 378206808998821888, 'category': 'Hashtags'},
#  {'tweet_id': 379319536878510082, 'category': 'Advice'},
#  {'tweet_id': 378226123764547584, 'category': 'MultimediaShare'},
#  {'tweet_id': 378050260792119297, 'category': 'MovePeople'},
#  {'tweet_id': 378211338851344384, 'category': 'Weather'},
#  {'tweet_id': 378056971686932480, 'category': 'ServiceAvailable'},
#  {'tweet_id': 378054979380334592, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 379421118697725953, 'category': 'Weather'},
#  {'tweet_id': 378079650250907648, 'category': 'ContinuingNews'},
#  {'tweet_id': 379119284019941376, 'category': 'Sentiment'},
#  {'tweet_id': 379189865776418817, 'category': 'MultimediaShare'},
#  {'tweet_id': 379387966948257792, 'category': 'EmergingThreats'},
#  {'tweet_id': 378082263302299649, 'category': 'Irrelevant'},
#  {'tweet_id': 379284581548949504, 'category': 'Advice'},
#  {'tweet_id': 378029784204206080, 'category': 'MultimediaShare'},
#  {'tweet_id': 379222237393719296, 'category': 'Advice'},
#  {'tweet_id': 379273391150080001, 'category': 'ContinuingNews'},
#  {'tweet_id': 378137582007496704, 'category': 'Irrelevant'},
#  {'tweet_id': 378081462223777793, 'category': 'Sentiment'},
#  {'tweet_id': 378189641708351488, 'category': 'Unknown'},
#  {'tweet_id': 378191675941588992, 'category': 'Factoid'},
#  {'tweet_id': 378224748016058368, 'category': 'Factoid'},
#  {'tweet_id': 378147442786439168, 'category': 'MultimediaShare'},
#  {'tweet_id': 378151544849305600, 'category': 'Donations'},
#  {'tweet_id': 379396951113859072, 'category': 'MultimediaShare'},
#  {'tweet_id': 379167765976088576, 'category': 'ContinuingNews'},
#  {'tweet_id': 379334183392251904, 'category': 'Donations'},
#  {'tweet_id': 379314377876189184, 'category': 'Irrelevant'},
#  {'tweet_id': 378174277947645952, 'category': 'Advice'},
#  {'tweet_id': 379109083452030977, 'category': 'MultimediaShare'},
#  {'tweet_id': 379385865597775872, 'category': 'ContinuingNews'},
#  {'tweet_id': 379380798882709504, 'category': 'Factoid'},
#  {'tweet_id': 378079067255238656, 'category': 'ContinuingNews'},
#  {'tweet_id': 378086805771268096, 'category': 'ContinuingNews'},
#  {'tweet_id': 379306253501341696, 'category': 'Weather'},
#  {'tweet_id': 378066689885077504, 'category': 'ContinuingNews'},
#  {'tweet_id': 379391708271620096, 'category': 'Factoid'},
#  {'tweet_id': 379367666500108288, 'category': 'Irrelevant'},
#  {'tweet_id': 378183031460069376, 'category': 'Factoid'},
#  {'tweet_id': 379324934935162881, 'category': 'EmergingThreats'},
#  {'tweet_id': 378152455005282306, 'category': 'EmergingThreats'},
#  {'tweet_id': 379313346060644352, 'category': 'MultimediaShare'},
#  {'tweet_id': 378134704710766592, 'category': 'Factoid'},
#  {'tweet_id': 378219136033112064, 'category': 'EmergingThreats'},
#  {'tweet_id': 378067142844747776, 'category': 'InformationWanted'},
#  {'tweet_id': 378203231262093312, 'category': 'MultimediaShare'},
#  {'tweet_id': 378201951969632256, 'category': 'Factoid'},
#  {'tweet_id': 379122991780888576, 'category': 'PastNews'},
#  {'tweet_id': 379262125211795457, 'category': 'Factoid'},
#  {'tweet_id': 379426239947481088, 'category': 'MultimediaShare'},
#  {'tweet_id': 378183627051237376, 'category': 'Sentiment'},
#  {'tweet_id': 379416429482606593, 'category': 'ContinuingNews'},
#  {'tweet_id': 379111939772665857, 'category': 'ContinuingNews'},
#  {'tweet_id': 379378101924278273, 'category': 'Discussion'},
#  {'tweet_id': 378088110170451969, 'category': 'ContinuingNews'},
#  {'tweet_id': 378059840569880576, 'category': 'Advice'},
#  {'tweet_id': 379300591182557185, 'category': 'Sentiment'},
#  {'tweet_id': 379277325377888256, 'category': 'ContinuingNews'},
#  {'tweet_id': 378173116125413376, 'category': 'Official'},
#  {'tweet_id': 378179877368631296, 'category': 'Discussion'},
#  {'tweet_id': 379217170670292992, 'category': 'Factoid'},
#  {'tweet_id': 379226196841472000, 'category': 'Factoid'},
#  {'tweet_id': 378213599551832065, 'category': 'MovePeople'},
#  {'tweet_id': 379126259143286784, 'category': 'Factoid'},
#  {'tweet_id': 379366240428384256, 'category': 'ContinuingNews'},
#  {'tweet_id': 379325207543947264, 'category': 'Irrelevant'},
#  {'tweet_id': 378175691449069568, 'category': 'Advice'},
#  {'tweet_id': 379381461561782273, 'category': 'ContinuingNews'},
#  {'tweet_id': 379211395138850816, 'category': 'Weather'},
#  {'tweet_id': 379103282745991168, 'category': 'Factoid'},
#  {'tweet_id': 379422980998045696, 'category': 'ContinuingNews'},
#  {'tweet_id': 379399283163664384, 'category': 'InformationWanted'},
#  {'tweet_id': 379235193586208768, 'category': 'Unknown'},
#  {'tweet_id': 379248464393023488, 'category': 'Factoid'},
#  {'tweet_id': 379225102115557376, 'category': 'ContinuingNews'},
#  {'tweet_id': 379249848513355777, 'category': 'Factoid'},
#  {'tweet_id': 379279619691532289, 'category': 'ContinuingNews'},
#  {'tweet_id': 379363098915647488, 'category': 'Irrelevant'},
#  {'tweet_id': 379416379150987264, 'category': 'ContinuingNews'},
#  {'tweet_id': 379415850660687872, 'category': 'ContinuingNews'},
#  {'tweet_id': 378042534863192064, 'category': 'Discussion'},
#  {'tweet_id': 378184214274768896, 'category': 'Discussion'},
#  {'tweet_id': 378122012742668288, 'category': 'ContinuingNews'},
#  {'tweet_id': 379311844516585473, 'category': 'Discussion'},
#  {'tweet_id': 378195496935776257, 'category': 'Factoid'},
#  {'tweet_id': 378221870731890688, 'category': 'EmergingThreats'},
#  {'tweet_id': 378038458024865792, 'category': 'Sentiment'},
#  {'tweet_id': 379316609258496001, 'category': 'Irrelevant'},
#  {'tweet_id': 378061807681695744, 'category': 'Irrelevant'},
#  {'tweet_id': 378115570287542273, 'category': 'ContinuingNews'},
#  {'tweet_id': 379287374947041280, 'category': 'MultimediaShare'},
#  {'tweet_id': 378075674088448001, 'category': 'ContinuingNews'},
#  {'tweet_id': 379378525557383169, 'category': 'Factoid'},
#  {'tweet_id': 379409471140675585, 'category': 'Discussion'},
#  {'tweet_id': 378178619048087552, 'category': 'Sentiment'},
#  {'tweet_id': 378200127443181570, 'category': 'EmergingThreats'},
#  {'tweet_id': 379373546901749760, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 378164870157721600, 'category': 'Irrelevant'},
#  {'tweet_id': 379136388379058178, 'category': 'Factoid'},
#  {'tweet_id': 379325744440041472, 'category': 'Advice'},
#  {'tweet_id': 379377925767700480, 'category': 'ContinuingNews'},
#  {'tweet_id': 379251534631956480, 'category': 'Factoid'},
#  {'tweet_id': 378219127640305664, 'category': 'MultimediaShare'},
#  {'tweet_id': 378128681677234176, 'category': 'Factoid'},
#  {'tweet_id': 379370296337113088, 'category': 'Irrelevant'},
#  {'tweet_id': 378095349547552768, 'category': 'Weather'},
#  {'tweet_id': 378026101588496385, 'category': 'MultimediaShare'},
#  {'tweet_id': 378213784101203968, 'category': 'MovePeople'},
#  {'tweet_id': 378045630251147265, 'category': 'MultimediaShare'},
#  {'tweet_id': 378216451670171648, 'category': 'Advice'},
#  {'tweet_id': 378214128038318080, 'category': 'MovePeople'},
#  {'tweet_id': 379269817603477504, 'category': 'ContinuingNews'},
#  {'tweet_id': 378143550510088192, 'category': 'Discussion'},
#  {'tweet_id': 379370682217271296, 'category': 'EmergingThreats'},
#  {'tweet_id': 379362016793604096, 'category': 'Irrelevant'},
#  {'tweet_id': 379428379050520576, 'category': 'Irrelevant'},
#  {'tweet_id': 378139846935457792, 'category': 'EmergingThreats'},
#  {'tweet_id': 378159971210649600, 'category': 'ContinuingNews'},
#  {'tweet_id': 378170578588291072, 'category': 'EmergingThreats'},
#  {'tweet_id': 378195668898021376, 'category': 'Irrelevant'},
#  {'tweet_id': 378127477928783872, 'category': 'MultimediaShare'},
#  {'tweet_id': 379264868286599168, 'category': 'Advice'},
#  {'tweet_id': 379370464121876480, 'category': 'MultimediaShare'},
#  {'tweet_id': 379244509173125120, 'category': 'Factoid'},
#  {'tweet_id': 378197732508184576, 'category': 'Irrelevant'},
#  {'tweet_id': 378220553699463168, 'category': 'EmergingThreats'},
#  {'tweet_id': 379385957843083264, 'category': 'ContinuingNews'},
#  {'tweet_id': 378223082869379072, 'category': 'MovePeople'},
#  {'tweet_id': 379393608278736897, 'category': 'Irrelevant'},
#  {'tweet_id': 378178661020495872, 'category': 'MultimediaShare'},
#  {'tweet_id': 379406849671319553, 'category': 'Factoid'},
#  {'tweet_id': 378069365855621120, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 379378227774754816, 'category': 'Factoid'},
#  {'tweet_id': 379228499505995776, 'category': 'EmergingThreats'},
#  {'tweet_id': 379288473863065600, 'category': 'SignificantEventChange'},
#  {'tweet_id': 378184491111841792, 'category': 'Irrelevant'},
#  {'tweet_id': 378172612805152768, 'category': 'Factoid'},
#  {'tweet_id': 378205533913632769, 'category': 'Advice'},
#  {'tweet_id': 378055482704814082, 'category': 'Irrelevant'},
#  {'tweet_id': 378184453362679808, 'category': 'Factoid'},
#  {'tweet_id': 379120898835349504, 'category': 'Irrelevant'},
#  {'tweet_id': 379315556479807488, 'category': 'Irrelevant'},
#  {'tweet_id': 379231162876854272, 'category': 'ContinuingNews'},
#  {'tweet_id': 379244622414757888, 'category': 'Irrelevant'},
#  {'tweet_id': 378213377262108672, 'category': 'MovePeople'},
#  {'tweet_id': 379111721665056768, 'category': 'Factoid'},
#  {'tweet_id': 378056556413079552, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 378073551749648384, 'category': 'Advice'},
#  {'tweet_id': 378020179214491649, 'category': 'MultimediaShare'},
#  {'tweet_id': 378141524623912960, 'category': 'EmergingThreats'},
#  {'tweet_id': 379245721288851456, 'category': 'Advice'},
#  {'tweet_id': 379295625155575808, 'category': 'Irrelevant'},
#  {'tweet_id': 379324788138721282, 'category': 'Factoid'},
#  {'tweet_id': 379287790166347776, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 379276767556403201, 'category': 'MultimediaShare'},
#  {'tweet_id': 379244903403749376, 'category': 'KnownAlready'},
#  {'tweet_id': 379288075387420672, 'category': 'Donations'},
#  {'tweet_id': 378101922013532160, 'category': 'CleanUp'},
#  {'tweet_id': 378047710659502080, 'category': 'Advice'},
#  {'tweet_id': 379379666412249088, 'category': 'Irrelevant'},
#  {'tweet_id': 378186965726007296, 'category': 'Factoid'},
#  {'tweet_id': 379328139379638273, 'category': 'Irrelevant'},
#  {'tweet_id': 378176358318628864, 'category': 'ContinuingNews'},
#  {'tweet_id': 379357990261755904, 'category': 'MultimediaShare'},
#  {'tweet_id': 379281997836738560, 'category': 'Weather'},
#  {'tweet_id': 379367024784203776, 'category': 'Irrelevant'},
#  {'tweet_id': 378133551272562688, 'category': 'ContinuingNews'},
#  {'tweet_id': 379334258856194049, 'category': 'MultimediaShare'},
#  {'tweet_id': 379254877488041984, 'category': 'ServiceAvailable'},
#  {'tweet_id': 378111510205464576, 'category': 'ContinuingNews'},
#  {'tweet_id': 379266038526775296, 'category': 'ContinuingNews'},
#  {'tweet_id': 378220373365362688, 'category': 'Discussion'},
#  {'tweet_id': 379341879927504896, 'category': 'Irrelevant'},
#  {'tweet_id': 378133446410784768, 'category': 'Factoid'},
#  {'tweet_id': 379105400856915968, 'category': 'Factoid'},
#  {'tweet_id': 378122948064067584, 'category': 'Factoid'},
#  {'tweet_id': 379347533828325376, 'category': 'ServiceAvailable'},
#  {'tweet_id': 379371030315159552, 'category': 'MultimediaShare'},
#  {'tweet_id': 379388998742843392, 'category': 'Discussion'},
#  {'tweet_id': 378161380462833664, 'category': 'ContinuingNews'},
#  {'tweet_id': 378057261081714688, 'category': 'MovePeople'},
#  {'tweet_id': 378069734916251648, 'category': 'Weather'},
#  {'tweet_id': 378130011292979200, 'category': 'Advice'},
#  {'tweet_id': 379251027091795970, 'category': 'Factoid'},
#  {'tweet_id': 378101930414710784, 'category': 'MultimediaShare'},
#  {'tweet_id': 378011169883037697, 'category': 'MultimediaShare'},
#  {'tweet_id': 379218143753035776, 'category': 'Factoid'},
#  {'tweet_id': 379288561939255296, 'category': 'Irrelevant'},
#  {'tweet_id': 378201062772981761, 'category': 'Irrelevant'},
#  {'tweet_id': 379303514607849472, 'category': 'ContinuingNews'},
#  {'tweet_id': 378072872280788992, 'category': 'MultimediaShare'},
#  {'tweet_id': 378215919031308288, 'category': 'Irrelevant'},
#  {'tweet_id': 379302940000792576, 'category': 'Sentiment'},
#  {'tweet_id': 378137695240732672, 'category': 'Irrelevant'},
#  {'tweet_id': 379411652178755585, 'category': 'ContinuingNews'},
#  {'tweet_id': 378046271996440576, 'category': 'EmergingThreats'},
#  {'tweet_id': 379358808134254592, 'category': 'ServiceAvailable'},
#  {'tweet_id': 378222998995881984, 'category': 'MultimediaShare'},
#  {'tweet_id': 379388977775513600, 'category': 'Sentiment'},
#  {'tweet_id': 379290814268338176, 'category': 'ContinuingNews'},
#  {'tweet_id': 378158079579127808, 'category': 'EmergingThreats'},
#  {'tweet_id': 378151578399559680, 'category': 'Factoid'},
#  {'tweet_id': 378097819992592384, 'category': 'Factoid'},
#  {'tweet_id': 378049119924674561, 'category': 'MovePeople'},
#  {'tweet_id': 379410586817527808, 'category': 'InformationWanted'},
#  {'tweet_id': 379213924287012864, 'category': 'Sentiment'},
#  {'tweet_id': 275503827141132288, 'category': 'MultimediaShare'},
#  {'tweet_id': 275864050758459392, 'category': 'ContinuingNews'},
#  {'tweet_id': 275755783193505792, 'category': 'ContinuingNews'},
#  {'tweet_id': 275680285725716480, 'category': 'Weather'},
#  {'tweet_id': 275213048640327680, 'category': 'Unknown'},
#  {'tweet_id': 275544222487158784, 'category': 'Sentiment'},
#  {'tweet_id': 275715488506593280, 'category': 'Sentiment'},
#  {'tweet_id': 275860582056484864, 'category': 'ContinuingNews'},
#  {'tweet_id': 275841976123920386, 'category': 'MultimediaShare'},
#  {'tweet_id': 275715933115404288, 'category': 'MultimediaShare'},
#  {'tweet_id': 275851241337282560, 'category': 'Irrelevant'},
#  {'tweet_id': 275531983508078592, 'category': 'Official'},
#  {'tweet_id': 275888692277694464, 'category': 'MultimediaShare'},
#  {'tweet_id': 275383752614625283, 'category': 'ContinuingNews'},
#  {'tweet_id': 275215644893523968, 'category': 'ContinuingNews'},
#  {'tweet_id': 275477948285452288, 'category': 'Irrelevant'},
#  {'tweet_id': 275216999653707776, 'category': 'Factoid'},
#  {'tweet_id': 275856941413191680, 'category': 'Irrelevant'},
#  {'tweet_id': 275086229647802368, 'category': 'InformationWanted'},
#  {'tweet_id': 275736539709972480, 'category': 'ContinuingNews'},
#  {'tweet_id': 275777719403442176, 'category': 'Official'},
#  {'tweet_id': 275753656660414464, 'category': 'EmergingThreats'},
#  {'tweet_id': 275648790696964096, 'category': 'Sentiment'},
#  {'tweet_id': 275853208482631681, 'category': 'ContinuingNews'},
#  {'tweet_id': 275690939241074689, 'category': 'Factoid'},
#  {'tweet_id': 275145688097095680, 'category': 'MultimediaShare'},
#  {'tweet_id': 275881465483505664, 'category': 'MultimediaShare'},
#  {'tweet_id': 275499767046471680, 'category': 'Irrelevant'},
#  {'tweet_id': 275562899731275776, 'category': 'ContinuingNews'},
#  {'tweet_id': 275883940139655168, 'category': 'Sentiment'},
#  {'tweet_id': 275231293854326784, 'category': 'Sentiment'},
#  {'tweet_id': 275538820215226368, 'category': 'Irrelevant'},
#  {'tweet_id': 275594730295922688, 'category': 'Irrelevant'},
#  {'tweet_id': 275670412313104385, 'category': 'Advice'},
#  {'tweet_id': 275545946341904384, 'category': 'Sentiment'},
#  {'tweet_id': 275530729390211072, 'category': 'ContinuingNews'},
#  {'tweet_id': 275254710653550592, 'category': 'Factoid'},
#  {'tweet_id': 275839581197307905, 'category': 'Irrelevant'},
#  {'tweet_id': 275268048536096769, 'category': 'ContinuingNews'},
#  {'tweet_id': 275538346258874368, 'category': 'Sentiment'},
#  {'tweet_id': 275229192499634176, 'category': 'MultimediaShare'},
#  {'tweet_id': 274863314985680896, 'category': 'MultimediaShare'},
#  {'tweet_id': 275484130681188352, 'category': 'Sentiment'},
#  {'tweet_id': 275555492573630464, 'category': 'Sentiment'},
#  {'tweet_id': 275478791323787264, 'category': 'Irrelevant'},
#  {'tweet_id': 274728321307271168, 'category': 'MultimediaShare'},
#  {'tweet_id': 275830798286979076, 'category': 'Factoid'},
#  {'tweet_id': 275092319802363906, 'category': 'Weather'},
#  {'tweet_id': 275774422680477696, 'category': 'Sentiment'},
#  {'tweet_id': 275746203369623552, 'category': 'Unknown'},
#  {'tweet_id': 275728885113581568, 'category': 'Irrelevant'},
#  {'tweet_id': 275755632202764288, 'category': 'Weather'},
#  {'tweet_id': 275241657971130369, 'category': 'Advice'},
#  {'tweet_id': 274843333308850177, 'category': 'MultimediaShare'},
#  {'tweet_id': 275132912259698689, 'category': 'Advice'},
#  {'tweet_id': 275833461699387392, 'category': 'Factoid'},
#  {'tweet_id': 275845188969193472, 'category': 'Weather'},
#  {'tweet_id': 275657179271426048, 'category': 'Factoid'},
#  {'tweet_id': 275344145776795648, 'category': 'Factoid'},
#  {'tweet_id': 275755820929646593, 'category': 'Sentiment'},
#  {'tweet_id': 275830068499058688, 'category': 'ContinuingNews'},
#  {'tweet_id': 275739182125690880, 'category': 'Factoid'},
#  {'tweet_id': 275780831551832066, 'category': 'Irrelevant'},
#  {'tweet_id': 275747197457403904, 'category': 'Sentiment'},
#  {'tweet_id': 275720467158024193, 'category': 'Discussion'},
#  {'tweet_id': 275417453838884864, 'category': 'ContinuingNews'},
#  {'tweet_id': 275339443982987264, 'category': 'Irrelevant'},
#  {'tweet_id': 275825618346721281, 'category': 'ContinuingNews'},
#  {'tweet_id': 274681584194560000, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275855943164649472, 'category': 'EmergingThreats'},
#  {'tweet_id': 275757473493835778, 'category': 'ContinuingNews'},
#  {'tweet_id': 275748426375901184, 'category': 'Irrelevant'},
#  {'tweet_id': 275545925382987776, 'category': 'Irrelevant'},
#  {'tweet_id': 275285492642246656, 'category': 'Weather'},
#  {'tweet_id': 275760120070279168, 'category': 'EmergingThreats'},
#  {'tweet_id': 275600040263827456, 'category': 'Sentiment'},
#  {'tweet_id': 275139929347067904, 'category': 'Factoid'},
#  {'tweet_id': 275110934119321600, 'category': 'Official'},
#  {'tweet_id': 275590003302739968, 'category': 'Discussion'},
#  {'tweet_id': 275268660896079873, 'category': 'Irrelevant'},
#  {'tweet_id': 275595439137513474, 'category': 'Factoid'},
#  {'tweet_id': 275801882780381186, 'category': 'Irrelevant'},
#  {'tweet_id': 275225006605217792, 'category': 'Factoid'},
#  {'tweet_id': 275630755172986880, 'category': 'Unknown'},
#  {'tweet_id': 275581044261019649, 'category': 'Sentiment'},
#  {'tweet_id': 275765815943512064, 'category': 'Weather'},
#  {'tweet_id': 275577646899949568, 'category': 'ContinuingNews'},
#  {'tweet_id': 275259576058789888, 'category': 'Sentiment'},
#  {'tweet_id': 275892546843078656, 'category': 'Official'},
#  {'tweet_id': 275860611424997376, 'category': 'Sentiment'},
#  {'tweet_id': 275893306020462593, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275730885792378880, 'category': 'EmergingThreats'},
#  {'tweet_id': 275045104501260288, 'category': 'Weather'},
#  {'tweet_id': 275448881771327489, 'category': 'Irrelevant'},
#  {'tweet_id': 275858384262144000, 'category': 'ContinuingNews'},
#  {'tweet_id': 275780265324974083, 'category': 'Discussion'},
#  {'tweet_id': 275866034655858688, 'category': 'EmergingThreats'},
#  {'tweet_id': 275677622321700865, 'category': 'ContinuingNews'},
#  {'tweet_id': 275269390725951490, 'category': 'Irrelevant'},
#  {'tweet_id': 275899106730336256, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275898817348526080, 'category': 'Sentiment'},
#  {'tweet_id': 275818798395846656, 'category': 'ContinuingNews'},
#  {'tweet_id': 275720005763624960, 'category': 'MultimediaShare'},
#  {'tweet_id': 275266509226536960, 'category': 'Official'},
#  {'tweet_id': 275633141719388161, 'category': 'Sentiment'},
#  {'tweet_id': 275742168486928384, 'category': 'Discussion'},
#  {'tweet_id': 275138029298012161, 'category': 'MultimediaShare'},
#  {'tweet_id': 275774200353026048, 'category': 'Irrelevant'},
#  {'tweet_id': 275094664414126080, 'category': 'ContinuingNews'},
#  {'tweet_id': 275797919137939456, 'category': 'EmergingThreats'},
#  {'tweet_id': 274660784620052480, 'category': 'Weather'},
#  {'tweet_id': 275857511813349377, 'category': 'Factoid'},
#  {'tweet_id': 275881650053869568, 'category': 'Irrelevant'},
#  {'tweet_id': 275524807070736384, 'category': 'Official'},
#  {'tweet_id': 275470343995527168, 'category': 'KnownAlready'},
#  {'tweet_id': 275511641112731648, 'category': 'Sentiment'},
#  {'tweet_id': 275891460505731072, 'category': 'Weather'},
#  {'tweet_id': 275102369325408257, 'category': 'Hashtags'},
#  {'tweet_id': 275209072410759168, 'category': 'MultimediaShare'},
#  {'tweet_id': 275588501767061505, 'category': 'Sentiment'},
#  {'tweet_id': 275738049646833664, 'category': 'Weather'},
#  {'tweet_id': 275729430360489984, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275121851880062976, 'category': 'Irrelevant'},
#  {'tweet_id': 275196611141976066, 'category': 'Factoid'},
#  {'tweet_id': 275860741461000192, 'category': 'Advice'},
#  {'tweet_id': 275514455515881472, 'category': 'ContinuingNews'},
#  {'tweet_id': 274317493407981568, 'category': 'Unknown'},
#  {'tweet_id': 275111806505213952, 'category': 'Discussion'},
#  {'tweet_id': 275889694703755264, 'category': 'ContinuingNews'},
#  {'tweet_id': 275263749382881280, 'category': 'Advice'},
#  {'tweet_id': 275573913960980480, 'category': 'Discussion'},
#  {'tweet_id': 275716184748470272, 'category': 'Irrelevant'},
#  {'tweet_id': 275798758015512578, 'category': 'Sentiment'},
#  {'tweet_id': 275799273898135553, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 275839576977833984, 'category': 'Sentiment'},
#  {'tweet_id': 275784837124718592, 'category': 'MultimediaShare'},
#  {'tweet_id': 275773952910045185, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 275754952708722688, 'category': 'Factoid'},
#  {'tweet_id': 275831779754131456, 'category': 'Irrelevant'},
#  {'tweet_id': 275441470406807552, 'category': 'MultimediaShare'},
#  {'tweet_id': 275469291242016768, 'category': 'ThirdPartyObservation'},
#  {'tweet_id': 275762955428192256, 'category': 'Sentiment'},
#  {'tweet_id': 275829418390327296, 'category': 'Irrelevant'},
#  {'tweet_id': 275857486672703488, 'category': 'MultimediaShare'},
#  {'tweet_id': 275783574630842369, 'category': 'MultimediaShare'},
#  {'tweet_id': 275362978235297795, 'category': 'Irrelevant'},
#  {'tweet_id': 275758320739045376, 'category': 'Irrelevant'},
#  {'tweet_id': 275688468808617985, 'category': 'ContinuingNews'},
#  {'tweet_id': 275091149578985472, 'category': 'Sentiment'},
#  {'tweet_id': 275192215519780865, 'category': 'ContinuingNews'},
#  {'tweet_id': 275552262946975744, 'category': 'Official'},
#  {'tweet_id': 275750242522116097, 'category': 'Sentiment'},
#  {'tweet_id': 275898683109801984, 'category': 'ContinuingNews'},
#  {'tweet_id': 275880635044855809, 'category': 'Irrelevant'},
#  {'tweet_id': 275237581124407296, 'category': 'Advice'},
#  {'tweet_id': 275889229165391872, 'category': 'EmergingThreats'},
#  {'tweet_id': 275815719772499971, 'category': 'ContinuingNews'},
#  {'tweet_id': 275812926395408384, 'category': 'Irrelevant'},
#  {'tweet_id': 275768714232750080, 'category': 'Irrelevant'},
#  {'tweet_id': 275457463321501697, 'category': 'Weather'},
#  {'tweet_id': 275477331726970881, 'category': 'Irrelevant'},
#  {'tweet_id': 275104294515113985, 'category': 'Irrelevant'},
#  {'tweet_id': 275660585063022592, 'category': 'InformationWanted'},
#  {'tweet_id': 275866043023519744, 'category': 'EmergingThreats'},
#  {'tweet_id': 275267612311695362, 'category': 'Irrelevant'},
#  {'tweet_id': 275586526249889793, 'category': 'Discussion'},
#  {'tweet_id': 275846640194170880, 'category': 'Donations'},
#  {'tweet_id': 275756030623875072, 'category': 'ContinuingNews'},
#  {'tweet_id': 275742843732127745, 'category': 'Weather'},
#  {'tweet_id': 275217511362994176, 'category': 'ContinuingNews'},
#  {'tweet_id': 275793833915195392, 'category': 'Weather'},
#  {'tweet_id': 275567672849223680, 'category': 'ContinuingNews'},
#  {'tweet_id': 275718579696066560, 'category': 'ContinuingNews'},
#  {'tweet_id': 275189841543716864, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275795436122537984, 'category': 'Sentiment'},
#  {'tweet_id': 275629761135525890, 'category': 'Unknown'},
#  {'tweet_id': 275131066744983552, 'category': 'Sentiment'},
#  {'tweet_id': 275065346233335808, 'category': 'Advice'},
#  {'tweet_id': 275575906238607360, 'category': 'Weather'},
#  {'tweet_id': 275683800531480577, 'category': 'MultimediaShare'},
#  {'tweet_id': 275764305985683456, 'category': 'Discussion'},
#  {'tweet_id': 275725785514524672, 'category': 'Weather'},
#  {'tweet_id': 275760145257086976, 'category': 'Discussion'},
#  {'tweet_id': 275835311362285568, 'category': 'MultimediaShare'},
#  {'tweet_id': 274530656321675264, 'category': 'Irrelevant'},
#  {'tweet_id': 275890088997691392, 'category': 'Sentiment'},
#  {'tweet_id': 275581262373199872, 'category': 'Irrelevant'},
#  {'tweet_id': 275835323970383872, 'category': 'Unknown'},
#  {'tweet_id': 275043753922789377, 'category': 'Weather'},
#  {'tweet_id': 275698631598829569, 'category': 'MultimediaShare'},
#  {'tweet_id': 275829279974096897, 'category': 'ContinuingNews'},
#  {'tweet_id': 275084874912784384, 'category': 'Discussion'},
#  {'tweet_id': 275878063923949568, 'category': 'MovePeople'},
#  {'tweet_id': 275899261915369472, 'category': 'ContinuingNews'},
#  {'tweet_id': 275438974821089281, 'category': 'Irrelevant'},
#  {'tweet_id': 275888641971216384, 'category': 'Unknown'},
#  {'tweet_id': 275727601664942082, 'category': 'Irrelevant'},
#  {'tweet_id': 275617991910117377, 'category': 'Weather'},
#  {'tweet_id': 275350823117156352, 'category': 'Weather'},
#  {'tweet_id': 275750573855354880, 'category': 'Sentiment'},
#  {'tweet_id': 275797776565149696, 'category': 'Unknown'},
#  {'tweet_id': 275773457994768384, 'category': 'Weather'},
#  {'tweet_id': 274432077594759169, 'category': 'Weather'},
#  {'tweet_id': 275654616560066560, 'category': 'Official'},
#  {'tweet_id': 275894396547899392, 'category': 'Weather'},
#  {'tweet_id': 275836406092414976, 'category': 'Weather'},
#  {'tweet_id': 275890592284831744, 'category': 'ContinuingNews'},
#  {'tweet_id': 275035356942983168, 'category': 'Irrelevant'},
#  {'tweet_id': 275763051897176064, 'category': 'Irrelevant'},
#  {'tweet_id': 275514925269536769, 'category': 'Advice'},
#  {'tweet_id': 275856454878130176, 'category': 'Irrelevant'},
#  {'tweet_id': 275117779202494464, 'category': 'Advice'},
#  {'tweet_id': 275801358479798273, 'category': 'Advice'},
#  {'tweet_id': 275541944975896576, 'category': 'Factoid'},
#  {'tweet_id': 275441143255285762, 'category': 'Irrelevant'},
#  {'tweet_id': 275105557009018880, 'category': 'Irrelevant'},
#  {'tweet_id': 275447799611539457, 'category': 'Weather'},
#  {'tweet_id': 275817892442943488, 'category': 'Irrelevant'},
#  {'tweet_id': 275575059005972480, 'category': 'ContinuingNews'},
#  {'tweet_id': 275584353604616192, 'category': 'Factoid'},
#  {'tweet_id': 275129993032499200, 'category': 'PastNews'},
#  {'tweet_id': 275276646846713857, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275577667875659776, 'category': 'Weather'},
#  {'tweet_id': 275483572868091904, 'category': 'Discussion'},
#  {'tweet_id': 275086955249807360, 'category': 'Unknown'},
#  {'tweet_id': 275540019781963777, 'category': 'Weather'},
#  {'tweet_id': 275607627768143872, 'category': 'ContinuingNews'},
#  {'tweet_id': 275504116569092096, 'category': 'Irrelevant'},
#  {'tweet_id': 275385744909033472, 'category': 'Sentiment'},
#  {'tweet_id': 275261073421115392, 'category': 'Unknown'},
#  {'tweet_id': 275784077943123968, 'category': 'EmergingThreats'},
#  {'tweet_id': 275095633273171968, 'category': 'ContinuingNews'},
#  {'tweet_id': 275720542621941760, 'category': 'Weather'},
#  {'tweet_id': 275877501895573504, 'category': 'Weather'},
#  {'tweet_id': 275763819458998272, 'category': 'Discussion'},
#  {'tweet_id': 275771495056285698, 'category': 'ContinuingNews'},
#  {'tweet_id': 275398264914857984, 'category': 'ContinuingNews'},
#  {'tweet_id': 275581753106780162, 'category': 'Weather'},
#  {'tweet_id': 275716881023918081, 'category': 'SignificantEventChange'},
#  {'tweet_id': 275164403098333184, 'category': 'InformationWanted'},
#  {'tweet_id': 275833683993317376, 'category': 'ContinuingNews'},
#  {'tweet_id': 275539692655628288, 'category': 'Irrelevant'},
#  {'tweet_id': 275747793035984898, 'category': 'ContinuingNews'},
#  {'tweet_id': 275533992558723072, 'category': 'Discussion'},
#  {'tweet_id': 396332300796846081, 'category': 'Discussion'},
#  {'tweet_id': 396319441031811072, 'category': 'Factoid'},
#  {'tweet_id': 396319302619394049, 'category': 'Factoid'},
#  {'tweet_id': 396325518573703168, 'category': 'ContinuingNews'},
#  {'tweet_id': 396324470022864896, 'category': 'SignificantEventChange'},
#  {'tweet_id': 396263979762196480, 'category': 'Irrelevant'},
#  {'tweet_id': 396332820878336000, 'category': 'MultimediaShare'},
#  {'tweet_id': 396322683257774081, 'category': 'FirstPartyObservation'},
#  {'tweet_id': 396330455303475200, 'category': 'Sentiment'},
#  {'tweet_id': 396331482911735808, 'category': 'Advice'},
#  {'tweet_id': 396325015273996288, 'category': 'ContinuingNews'},
#  ...]

# %% [markdown]
# ## categoryMap()
# - `category_df`
# - `tweet_category_map`
# - `tweet_id_to_category`

# %%
# categoryMap()
# Maps a list of tweetIDs associated with categories

tweet_category_map = {}
category_df = pd.read_csv("tweet_to_category.csv")

cat_update_map = {
    "ContinuingNews": "News",
    "PastNews": "ContextualInformation",
    "KnownAlready": "OriginalEvent",
    "SignificantEventChange": "NewSubEvent",
}

category_df["category"] = category_df["category"].apply(lambda x: cat_update_map.get(x, x))
i = 0
for category, tweets in category_df.groupby("category"):
    print(i, category)
    i += 1
    tweet_category_map[category] = list(tweets["tweet_id"])
    
# Deleted in 2019
#del(tweet_category_map["Unknown"])

# Get a count of the category labels
category_to_label = {c:i+1 for i, c in enumerate(tweet_category_map.keys())}

tweet_id_to_category = {}

for category, tweet_ids in tweet_category_map.items():
   
        
    for tweet_id in tweet_ids:
        tweet_id_to_category[np.int64(tweet_id)] = category_to_label[category]
        
#tweet_id_to_category
#tweet_category_map
#tweet_id_to_priority
# Out:
# 0 Advice
# 1 CleanUp
# 2 ContextualInformation
# 3 Discussion
# 4 Donations
# 5 EmergingThreats
# 6 Factoid
# 7 FirstPartyObservation
# 8 Hashtags
# 9 InformationWanted
# 10 Irrelevant
# 11 MovePeople
# 12 MultimediaShare
# 13 NewSubEvent
# 14 News
# 15 Official
# 16 OriginalEvent
# 17 Sentiment
# 18 ServiceAvailable
# 19 ThirdPartyObservation
# 20 Unknown
# 21 Volunteer
# 22 Weather

# %% [markdown]
# Maps the tweetID in `tweet_id_to_priority` to it's numerical priority value. We can then use this to calculate the error against our run
#
# Outputs `priority_df` and `priority_map` (identical)

# %%
priority_df = pd.DataFrame(tweet_id_to_priority)

priority_mapping = {
    "Critical" : 1,
    "High" : 0.75,
    "Medium" : 0.5,
    "Low" : 0.25,
    "Unknown" : 0,
}


temp_merged_priorities = []
for tweet_id, group in priority_df.groupby("tweet_id"):
    priority_list = list(group["priority"])
    p_scores = [priority_mapping[p] for p in priority_list]
    temp_merged_priorities.append({
        "tweet_id": tweet_id,
        "priority": np.mean(p_scores),
    })

priority_df = pd.DataFrame(temp_merged_priorities)
priority_map = {row["tweet_id"]: row["priority"] for idx, row in priority_df.iterrows()}

#priority_df.head()

# %% [markdown]
# #### ID -> EventID
#
# Returns a map of events with all identified tweet IDs
#
# ```
# {'albertaFloods2013': [347686624563429376,
#   347766337344503808,
#   347783236191129600,
#   347793432514801664,
# ```

# %%
print("Labels:", sum([len(v) for v in tweet_category_map.values()]))
# Out:
# Labels: 1335

# %%
# Instantiate a new DataFrame to hold the categorised_tweets
cat_df = pd.DataFrame.from_records([tweet_id_to_category])
cat_df = cat_df.transpose()
cat_df = cat_df.reset_index()
cat_df.columns = ['tweet_id', 'postCategories']
#cat_df

# %% [markdown]
# ## Merge the category and priority

# %%
tweet_to_category_priority_df = priority_df.join(category_df.set_index('tweet_id'), on='tweet_id')
tweet_to_category_id_priority_df = tweet_to_category_priority_df.join(cat_df.set_index('tweet_id'), on='tweet_id')
tweet_to_category_id_priority_df
# Out:
#                 tweet_id  priority               category  postCategories
# 0     211281973870727170      0.25             Irrelevant              11
# 1     211557401231495171      0.50  FirstPartyObservation               8
# 2     211565974422425600      0.75       ServiceAvailable              19
# 3     211607187653533697      0.50                Weather              23
# 4     211654415503990784      0.50                   News              15
# ...                  ...       ...                    ...             ...
# 1330  396336012726525952      0.25                   News              15
# 1331  396336079856345088      0.25                   News              15
# 1332  396336243442589696      0.25                   News              15
# 1333  396336297968562176      0.25                Factoid               7
# 1334  396336394429562880      0.25                   News              15
#
# [1335 rows x 4 columns]

# %%
# 
merged_df = pd.merge(tweet_to_category_id_priority_df, labels_df, left_on = 'tweet_id', right_on = 'postID', how = 'inner')

#merged_df['eventID'] = merged_df['eventID'].str[-2:]
#merged_df.loc[merged_df['postCategories_x'] == 8]

merged_df
# Out:
#                tweet_id  priority          category  postCategories_x  \
# 0    211565974422425600      0.75  ServiceAvailable                19
# 1    211654415503990784      0.50              News                15
# 2    211681309368655872      0.25              News                15
# 3    211685621125742592      0.25          Official                16
# 4    211877049147736064      0.25           Factoid                 7
# ..                  ...       ...               ...               ...
# 938  396336012726525952      0.25              News                15
# 939  396336079856345088      0.25              News                15
# 940  396336243442589696      0.25              News                15
# 941  396336297968562176      0.25           Factoid                 7
# 942  396336394429562880      0.25              News                15
#
#                    eventID                                  eventName  \
# 0         fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# 1         fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# 2         fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# 3         fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# 4         fireColorado2012  DEMO: CrisisLex26 2012 Colorado wildfires
# ..                     ...                                        ...
# 938  laAirportShooting2013       CrisisLex26 2013 LA Airport Shooting
# 939  laAirportShooting2013       CrisisLex26 2013 LA Airport Shooting
# 940  laAirportShooting2013       CrisisLex26 2013 LA Airport Shooting
# 941  laAirportShooting2013       CrisisLex26 2013 LA Airport Shooting
# 942  laAirportShooting2013       CrisisLex26 2013 LA Airport Shooting
#
#                                       eventDescription eventType  \
# 0    The 2012 Colorado wildfires were an unusually ...   Unknown
# 1    The 2012 Colorado wildfires were an unusually ...   Unknown
# 2    The 2012 Colorado wildfires were an unusually ...   Unknown
# 3    The 2012 Colorado wildfires were an unusually ...   Unknown
# 4    The 2012 Colorado wildfires were an unusually ...   Unknown
# ..                                                 ...       ...
# 938  On November 1, 2013, a shooting occurred at ar...   Unknown
# 939  On November 1, 2013, a shooting occurred at ar...   Unknown
# 940  On November 1, 2013, a shooting occurred at ar...   Unknown
# 941  On November 1, 2013, a shooting occurred at ar...   Unknown
# 942  On November 1, 2013, a shooting occurred at ar...   Unknown
#
#                  postID    postCategories_y postPriority
# 0    211565974422425600  [ServiceAvailable]         High
# 1    211654415503990784              [News]       Medium
# 2    211681309368655872              [News]          Low
# 3    211685621125742592          [Official]          Low
# 4    211877049147736064           [Factoid]          Low
# ..                  ...                 ...          ...
# 938  396336012726525952              [News]          Low
# 939  396336079856345088              [News]          Low
# 940  396336243442589696              [News]          Low
# 941  396336297968562176           [Factoid]          Low
# 942  396336394429562880              [News]          Low
#
# [943 rows x 11 columns]

# %%
'''
'Advice':1
Cleanup
ContextualInformation
Discussion
Donations
EmergingThreats
Factoid
FirstPartyObservation


'''
# Drop irrelevant columns
df = merged_df.drop(['postID','eventName','eventDescription','postPriority', 'postCategories_y'],axis =1)
df.to_csv("dataset_labelled_tweets.csv", index=False)
# Drop string
#df = df.drop(['category','eventID','eventType',],axis =1)

df
# Out:
#                tweet_id  priority          category  postCategories_x  \
# 0    211565974422425600      0.75  ServiceAvailable                19
# 1    211654415503990784      0.50              News                15
# 2    211681309368655872      0.25              News                15
# 3    211685621125742592      0.25          Official                16
# 4    211877049147736064      0.25           Factoid                 7
# ..                  ...       ...               ...               ...
# 938  396336012726525952      0.25              News                15
# 939  396336079856345088      0.25              News                15
# 940  396336243442589696      0.25              News                15
# 941  396336297968562176      0.25           Factoid                 7
# 942  396336394429562880      0.25              News                15
#
#                    eventID eventType
# 0         fireColorado2012   Unknown
# 1         fireColorado2012   Unknown
# 2         fireColorado2012   Unknown
# 3         fireColorado2012   Unknown
# 4         fireColorado2012   Unknown
# ..                     ...       ...
# 938  laAirportShooting2013   Unknown
# 939  laAirportShooting2013   Unknown
# 940  laAirportShooting2013   Unknown
# 941  laAirportShooting2013   Unknown
# 942  laAirportShooting2013   Unknown
#
# [943 rows x 6 columns]

# %%
df.sort_values(by=['postCategories_x'])


df.loc[df['postCategories_x'] == 15]
# Out:
#                tweet_id  priority category  postCategories_x  \
# 1    211654415503990784      0.50     News                15
# 2    211681309368655872      0.25     News                15
# 12   212099863171710976      0.25     News                15
# 13   212137133736075264      0.25     News                15
# 24   212298199229149184      0.25     News                15
# ..                  ...       ...      ...               ...
# 937  396335979167903744      0.25     News                15
# 938  396336012726525952      0.25     News                15
# 939  396336079856345088      0.25     News                15
# 940  396336243442589696      0.25     News                15
# 942  396336394429562880      0.25     News                15
#
#                    eventID eventType
# 1         fireColorado2012   Unknown
# 2         fireColorado2012   Unknown
# 12        fireColorado2012   Unknown
# 13        fireColorado2012   Unknown
# 24        fireColorado2012   Unknown
# ..                     ...       ...
# 937  laAirportShooting2013   Unknown
# 938  laAirportShooting2013   Unknown
# 939  laAirportShooting2013   Unknown
# 940  laAirportShooting2013   Unknown
# 942  laAirportShooting2013   Unknown
#
# [179 rows x 6 columns]

# %% [markdown]
# ## Export to CSV

# %%
#clean_dataset(df)

# Export to CSV
#merged_df.to_csv("train.csv", index=False)
df.to_csv("dataset.csv", index=False)
df = pd.read_csv("dataset.csv")
df
# Out:
#                tweet_id  priority          category  postCategories_x  \
# 0    211565974422425600      0.75  ServiceAvailable                19
# 1    211654415503990784      0.50              News                15
# 2    211681309368655872      0.25              News                15
# 3    211685621125742592      0.25          Official                16
# 4    211877049147736064      0.25           Factoid                 7
# ..                  ...       ...               ...               ...
# 938  396336012726525952      0.25              News                15
# 939  396336079856345088      0.25              News                15
# 940  396336243442589696      0.25              News                15
# 941  396336297968562176      0.25           Factoid                 7
# 942  396336394429562880      0.25              News                15
#
#                    eventID eventType
# 0         fireColorado2012   Unknown
# 1         fireColorado2012   Unknown
# 2         fireColorado2012   Unknown
# 3         fireColorado2012   Unknown
# 4         fireColorado2012   Unknown
# ..                     ...       ...
# 938  laAirportShooting2013   Unknown
# 939  laAirportShooting2013   Unknown
# 940  laAirportShooting2013   Unknown
# 941  laAirportShooting2013   Unknown
# 942  laAirportShooting2013   Unknown
#
# [943 rows x 6 columns]

# %%
df
#clean_dataset(df)
mapping = {'fireColorado2012': 1, 'costaRicaEarthquake2012': 2,
          'floodColorado2013': 3, 'typhoonPablo2012': 4,
          'laAirportShooting2013': 5, 'westTexasExplosion2013': 6,
          'guatemalaEarthquake2012': 7, 'italyEarthquakes2012': 8,
          'philipinnesFloods2012': 9, 'albertaFloods2013': 10, 
           'australiaBushfire2013': 11, 'bostonBombings2013': 12,
           'siberianWildfires2019': 46
          }
df = df.replace({'eventID': mapping})
df
# Out:
#                tweet_id  priority          category  postCategories_x  \
# 0    211565974422425600      0.75  ServiceAvailable                19
# 1    211654415503990784      0.50              News                15
# 2    211681309368655872      0.25              News                15
# 3    211685621125742592      0.25          Official                16
# 4    211877049147736064      0.25           Factoid                 7
# ..                  ...       ...               ...               ...
# 938  396336012726525952      0.25              News                15
# 939  396336079856345088      0.25              News                15
# 940  396336243442589696      0.25              News                15
# 941  396336297968562176      0.25           Factoid                 7
# 942  396336394429562880      0.25              News                15
#
#      eventID eventType
# 0          1   Unknown
# 1          1   Unknown
# 2          1   Unknown
# 3          1   Unknown
# 4          1   Unknown
# ..       ...       ...
# 938        5   Unknown
# 939        5   Unknown
# 940        5   Unknown
# 941        5   Unknown
# 942        5   Unknown
#
# [943 rows x 6 columns]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    df.astype(int)
    return df[indices_to_keep].astype(np.float64)

df.sort_values(by=['label_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-6c63f2b9028b> in <module>
#       6     return df[indices_to_keep].astype(np.float64)
#       7
# ----> 8 df.sort_values(by=['label_id'])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5289
#    5290             by = by[0]
# -> 5291             k = self._get_label_or_level_values(by, axis=axis)
#    5292
#    5293             # need to rewrap column in Series to apply key function
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1558             values = self.axes[axis].get_level_values(key)._values
#    1559         else:
# -> 1560             raise KeyError(key)
#    1561
#    1562         # Check for duplicates
#
# KeyError: 'label_id'

# %%
df = df.drop(['id','intentType','category'],axis =1)

df
