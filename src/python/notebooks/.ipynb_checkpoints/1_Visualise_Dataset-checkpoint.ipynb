# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
df = pd.read_csv("selected.csv")
df.head()
# Out:
#    Unnamed: 0      tweet_id  positive_sentiment  negative_sentiment  \
# 0           0  1.155679e+18                  20                 630
# 1           1  1.155712e+18                  40                 580
# 2           2  1.155790e+18                  70                 500
# 3           3  1.155810e+18                  20                 630
# 4           4  1.155847e+18                  60                 530
#
#    numb_of_questions  tweet_length  userFollowersCount  userFriendsCount  \
# 0                190          1000              145000             13700
# 1                150           740                 700              7030
# 2                430          2300               37260             10130
# 3                180           990              679280            393110
# 4                460          2370               18320             33710
#
#    user_list_count  dict_precision  dict_recall  dict_f_measure
# 0                0               0            0               0
# 1               10               0            0               0
# 2             7990               0            0               0
# 3            13300               0            0               0
# 4              190               0            0               0

# %%
sns.countplot(x="negative_sentiment",hue="positive_sentiment",data=df)

# %%
sns.jointplot(data=df, x="negative_sentiment", y="userFollowersCount", hue="timestamp",height = 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-970b9240cb86> in <module>
# ----> 1 sns.jointplot(data=df, x="negative_sentiment", y="userFollowersCount", hue="timestamp",height = 10)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2054
#    2055     # Initialize the JointGrid object
# -> 2056     grid = JointGrid(
#    2057         data=data, x=x, y=y, hue=hue,
#    2058         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1589
#    1590         # Process the input variables
# -> 1591         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1592         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1593
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `timestamp` for parameter `hue`

# %%
sns.jointplot(x=df['negative_sentiment'], y=df['tweet_length'], data=df, kind='reg')
#plt.scatter(df['negative_sentiment'], df['tweet_length'])

# %%
df.describe()
# Out:
#        Unnamed: 0      tweet_id  positive_sentiment  negative_sentiment  \
# count  281.000000  2.810000e+02          281.000000          281.000000
# mean   140.000000  1.157416e+18           95.587189          434.982206
# std     81.261922  8.076043e+14           95.163921          173.980961
# min      0.000000  1.155679e+18           10.000000           60.000000
# 25%     70.000000  1.156849e+18           30.000000          290.000000
# 50%    140.000000  1.157304e+18           60.000000          470.000000
# 75%    210.000000  1.158115e+18          110.000000          570.000000
# max    280.000000  1.158759e+18          440.000000          740.000000
#
#        numb_of_questions  tweet_length  userFollowersCount  userFriendsCount  \
# count         281.000000    281.000000        2.810000e+02        281.000000
# mean          167.402135    910.640569        2.031941e+06      25224.306050
# std           116.628279    545.898619        1.438755e+07      52049.687912
# min            50.000000    280.000000        0.000000e+00          0.000000
# 25%           100.000000    620.000000        1.530000e+03       1280.000000
# 50%           120.000000    690.000000        9.410000e+03       8450.000000
# 75%           170.000000    870.000000        4.050000e+04      27240.000000
# max           600.000000   2850.000000        1.445414e+08     441340.000000
#
#        user_list_count  dict_precision   dict_recall  dict_f_measure
# count       281.000000    2.810000e+02  2.810000e+02    2.810000e+02
# mean      11138.932384    4.540502e+15  7.523961e+15    5.752740e+15
# std       60502.726434    6.757477e+15  6.874819e+15    6.964256e+15
# min           0.000000    0.000000e+00  0.000000e+00    0.000000e+00
# 25%          30.000000    0.000000e+00  0.000000e+00    0.000000e+00
# 50%         150.000000    1.000000e+02  1.111000e+16    1.250000e+02
# 75%        1340.000000    1.111000e+16  1.111000e+16    1.111000e+16
# max      566730.000000    2.222000e+16  2.222000e+16    2.222000e+16

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7a0270670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd7a09fff70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd7a0564e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7a10eaf40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd7a1583400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a38fb80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a38fc70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a42d160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a455970>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a478dc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a4a6250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd78a4ca6a0>]],
#       dtype=object)

# %%
# Needs timestamp as index
#df = df.reset_index()


sns.set()
df_plot = df.resample('10Min').mean()
plt.plot(df_plot)
plt.title('x')
plt.ylabel('y')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1074b272ece3> in <module>
#       3
#       4 sns.set()
# ----> 5 df_plot = df.resample('10Min').mean()
#       6 plt.plot(df_plot)
#       7 plt.title('x')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8066
#    8067         axis = self._get_axis_number(axis)
# -> 8068         return get_resampler(
#    8069             self,
#    8070             freq=rule,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1432             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1433
# -> 1434         raise TypeError(
#    1435             "Only valid with DatetimeIndex, "
#    1436             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
# jointplot
sns.jointplot(data=df, x="tweet_length", y="userFollowersCount", hue="negative_sentiment",height = 5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.plot(figsize=(18,5))

# %%
sns.lmplot(x='tweet_length', y='userFollowersCount', hue='negative_sentiment', data=df, fit_reg=False)
