# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
df = pd.read_csv("selected.csv")
df.head()
# Out:
#        tweet_id  positive_sentiment  negative_sentiment  numb_of_questions  \
# 0  1.155679e+18                  20                 630                190
# 1  1.155712e+18                  40                 580                150
# 2  1.155790e+18                  70                 500                430
# 3  1.155810e+18                  20                 630                180
# 4  1.155847e+18                  60                 530                460
#
#    tweet_length  userFollowersCount  userFriendsCount  user_list_count  \
# 0          1000              145000             13700                0
# 1           740                 700              7030               10
# 2          2300               37260             10130             7990
# 3           990              679280            393110            13300
# 4          2370               18320             33710              190
#
#    dict_precision  dict_recall  dict_f_measure
# 0               0            0               0
# 1               0            0               0
# 2               0            0               0
# 3               0            0               0
# 4               0            0               0

# %%
sns.countplot(x="negative_sentiment",hue="positive_sentiment",data=df)

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(corrmat, vmax=1, square=True,cmap="Greys");
ax.set_title('Correlation between model variables')
plt.show()

# %%
sns.heatmap(df.corr())
plt.title('Heatmap')
plt.savefig('heatmap.png')

# %%
df_box = df.drop(['negative_sentiment', 'dict_precision'], axis=1)
df_box.boxplot()
plt.xticks(rotation=45)
plt.xlabel('Features')
plt.title('Boxplot')
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
#sns.distplot(df["priority"].dropna())
#df["priority"].plot.hist(bins=4)

# %%
sns.jointplot(data=df, x="negative_sentiment", y="userFollowersCount", hue="dict_recall",height = 10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x=df['negative_sentiment'], y=df['tweet_length'], data=df, kind='reg')
#plt.scatter(df['negative_sentiment'], df['tweet_length'])

# %%
df.describe()
# Out:
#            tweet_id  positive_sentiment  negative_sentiment  \
# count  2.810000e+02          281.000000          281.000000
# mean   1.157416e+18           95.587189          434.982206
# std    8.076043e+14           95.163921          173.980961
# min    1.155679e+18           10.000000           60.000000
# 25%    1.156849e+18           30.000000          290.000000
# 50%    1.157304e+18           60.000000          470.000000
# 75%    1.158115e+18          110.000000          570.000000
# max    1.158759e+18          440.000000          740.000000
#
#        numb_of_questions  tweet_length  userFollowersCount  userFriendsCount  \
# count         281.000000    281.000000        2.810000e+02        281.000000
# mean          167.402135    910.640569        2.031941e+06      25224.306050
# std           116.628279    545.898619        1.438755e+07      52049.687912
# min            50.000000    280.000000        0.000000e+00          0.000000
# 25%           100.000000    620.000000        1.530000e+03       1280.000000
# 50%           120.000000    690.000000        9.410000e+03       8450.000000
# 75%           170.000000    870.000000        4.050000e+04      27240.000000
# max           600.000000   2850.000000        1.445414e+08     441340.000000
#
#        user_list_count  dict_precision   dict_recall  dict_f_measure
# count       281.000000    2.810000e+02  2.810000e+02    2.810000e+02
# mean      11138.932384    4.540502e+15  7.523961e+15    5.752740e+15
# std       60502.726434    6.757477e+15  6.874819e+15    6.964256e+15
# min           0.000000    0.000000e+00  0.000000e+00    0.000000e+00
# 25%          30.000000    0.000000e+00  0.000000e+00    0.000000e+00
# 50%         150.000000    1.000000e+02  1.111000e+16    1.250000e+02
# 75%        1340.000000    1.111000e+16  1.111000e+16    1.111000e+16
# max      566730.000000    2.222000e+16  2.222000e+16    2.222000e+16

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fccc874d2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc88e4c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8930130>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8968520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8994970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc89c1d00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fccc89c1df0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc89fb2e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8a53af0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8a81f40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8aba3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fccc8ae6760>]],
#       dtype=object)

# %%
# jointplot
sns.jointplot(data=df, x="tweet_length", y="userFollowersCount", hue="negative_sentiment",height = 5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.plot(figsize=(18,5))

# %%
sns.lmplot(x='tweet_length', y='userFollowersCount', hue='negative_sentiment', data=df, fit_reg=False)

# %%
# Needs timestamp as index
#df = df.reset_index()


sns.set()
df_plot = df.resample('10Min').mean()
plt.plot(df_plot)
plt.title('x')
plt.ylabel('y')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-dd00290e1efb> in <module>
#       4
#       5 sns.set()
# ----> 6 df_plot = df.resample('10Min').mean()
#       7 plt.plot(df_plot)
#       8 plt.title('x')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8066
#    8067         axis = self._get_axis_number(axis)
# -> 8068         return get_resampler(
#    8069             self,
#    8070             freq=rule,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1432             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1433
# -> 1434         raise TypeError(
#    1435             "Only valid with DatetimeIndex, "
#    1436             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'
