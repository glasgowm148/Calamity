# %%
from datetime import datetime
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn import utils

# %%
# Reload the data to check everythings went alright
df = pd.read_csv("feature_vec.csv")

# Timestamp will need to be reconfigured as index on each load
#df = df.set_index('timestamp')
df
# Out:
#                      tweet_id            timestamp positive_sentiment  \
# 0     1.15548485241168691E18,  2019-07-28 14:27:11               2.0,
# 1     1.15548673102360576E18,  2019-07-28 14:34:39               1.0,
# 2     1.15548843001874432E18,  2019-07-28 14:41:24               2.0,
# 3     1.15549353099270554E18,  2019-07-28 15:01:40               4.0,
# 4     1.15549548994669773E18,  2019-07-28 15:09:27              15.0,
# ...                       ...                  ...                ...
# 2944   1.1587591256033239E18,  2019-08-06 15:17:58               3.0,
# 2945  1.15875932609122714E18,  2019-08-06 15:18:46               7.0,
# 2946  1.15875993376617677E18,  2019-08-06 15:21:11               5.0,
# 2947  1.15876167494759629E18,  2019-08-06 15:28:06               9.0,
# 2948  1.15876260841501082E18,  2019-08-06 15:31:49               3.0,
#
#      negative_sentiment numb_of_questions tweet_length userFollowersCount  \
# 0                 66.0,             15.0,        99.0,              18.0,
# 1                 39.0,             52.0,       257.0,            7709.0,
# 2                 63.0,             17.0,        98.0,             537.0,
# 3                 57.0,             63.0,       257.0,             295.0,
# 4                 42.0,             40.0,       217.0,            1682.0,
# ...                 ...               ...          ...                ...
# 2944              65.0,              8.0,        57.0,             550.0,
# 2945              47.0,             15.0,        80.0,             106.0,
# 2946              37.0,             12.0,        57.0,             220.0,
# 2947              28.0,              8.0,        70.0,              33.0,
# 2948              19.0,              9.0,        68.0,            1592.0,
#
#      userFriendsCount user_list_count       dict_precision  \
# 0               42.0,            0.0,  11.109999656677246,
# 1             2814.0,          392.0,                 0.0,
# 2             1486.0,           20.0,                 0.0,
# 3             2145.0,            2.0,                10.0,
# 4              104.0,           51.0,                 0.0,
# ...               ...             ...                  ...
# 2944           720.0,            7.0,  14.289999961853027,
# 2945           124.0,            0.0,  22.219999313354492,
# 2946            61.0,            3.0,   33.33000183105469,
# 2947             0.0,            4.0,  16.670000076293945,
# 2948           523.0,           94.0,                20.0,
#
#               dict_recall       dict_f_measure
# 0     11.109999656677246,  11.109999656677246]
# 1                    0.0,                 0.0]
# 2                    0.0,                 0.0]
# 3     11.109999656677246,  10.529999732971191]
# 4                    0.0,                 0.0]
# ...                   ...                  ...
# 2944  11.109999656677246,                12.5]
# 2945  22.219999313354492,  22.219999313354492]
# 2946  22.219999313354492,  26.670000076293945]
# 2947  11.109999656677246,  13.329999923706055]
# 2948  11.109999656677246,  14.289999961853027]
#
# [2949 rows x 12 columns]

# %%
#lab_enc = preprocessing.LabelEncoder()
#encoded = lab_enc.fit_transform(df)

# %%
# github.com/SSaishruthi/Linear_Regression_Detailed_Implementation

# Data must be 1-dimensional

def lin_reg():
    x_train, x_test, y_train, y_test = train_test_split(df['negative_sentiment'], df['dict_f_measure'], test_size=0.2, random_state=42)
    x_train = np.reshape(x_train, (-1,1))
    x_test = np.reshape(x_test, (-1,1))
    y_train = np.reshape(y_train, (-1,1))
    y_test = np.reshape(y_test, (-1,1))

    
    print('Train - Predictors shape', x_train.shape)
    print('Test - Predictors shape', x_test.shape)
    print('Train - Target shape', y_train.shape)
    print('Test - Target shape', y_test.shape)

# lin_reg()

# %%
# LinearRegression() 

X = pd.DataFrame(df['tweet_id'])
y = pd.DataFrame(df['postCategories_x'])

# Instantiate a new model
model = LinearRegression()

scores = []

# kfold
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Iterate through the X, y dataframe
for i, (train, test) in enumerate(kfold.split(X, y)):
    
    model.fit(X.iloc[train,:], y.iloc[train,:])
    
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    
    scores.append(score)

    
print(scores)
# Out:
# [-0.05124454751459995, 0.0011440101399238234, 0.012533492447670436, 0.012938082048204791, 0.029223980088389223]

# %% [markdown]
# ## Scores
#
# ```python
# # original
# [0.3426196251381527, 0.311339103472439, 0.33368357019140715]
#
# # timestamp
# [0.3007490969521819, 0.5248583809803089, 0.5786456480325219]
#
# # timestamp as index
# [0.30875457014518726, 0.21479123959592017, 0.2257684657713871]
# [0.3369114843455352, 0.36012522754170384, 0.5287437875934085, 0.5775024426976063, 0.5476392189848873]
#
# # id_str in:
# [0.5594252446769894, -1.1064712067528064, -1.0093894389647065, -0.6654363444184817, 0.9774333318197981]
#
# ## Relevant tweets:
# [-0.00437235175323103, -0.00258666225466353, -0.0009634590686360411, -0.0001166286295464225,-0.0008683094428452165]
#
# # added 'result' :
# [0.05705897121485326, 0.06305362537695913, 0.06681661573584774, 0.019871364437980987, 0.07613106249149648]
#
# # unncommented more of the tweet data
# [-0.0072474070012518155, 0.04745193780543566, 0.08582443214637303, 0.04446855090675339, 0.08504924837360017]
#
# # 'selected.json' from alberta wildfires
# [-0.0009070847214716071, -0.03632652408831483, -0.10067366175174541, -0.007240049777304414, -0.006228444123674182]
#
# # Getting one of the right labels in
# [-0.05124454751459995, 0.0011440101399238234, 0.012533492447670436, 0.012938082048204791, 0.029223980088389223]
#
# ```
