# %%
# Random Forest Algorithm
# seeding the generated number makes our results reproducible (good for debugging)
# This module implements pseudo-random number generators for various distributions.
from csv import reader
from datetime import datetime
from math import sqrt
from matplotlib import pyplot
from random import randrange
from random import seed
from sklearn import metrics

from sklearn import preprocessing
from sklearn import svm, datasets
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,log_loss
from sklearn.metrics import auc
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import itertools
import matplotlib.pyplot as plt
import numpy as np
import numpy as npX
import pandas as pd
import seaborn as sns

import time

#different models to compare:
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC

# %%
tweets = pd.read_csv("train.csv")
tweets.head()
tweets.drop
#tweets.fillna(0)
#np.isnan(tweets.values.any())
#df = tweets
# Out:
#              tweet_id  priority          category  event_id  \
# 0  211565974422425600      0.75  ServiceAvailable      19.0
# 1  211654415503990784      0.50              News      15.0
# 2  211681309368655872      0.25              News      15.0
# 3  211685621125742592      0.25          Official      16.0
# 4  211877049147736064      0.25           Factoid       7.0
#
#                  identifier  \
# 0  TRECIS-ITR-H-Types-v4-T1
# 1  TRECIS-ITR-H-Types-v4-T1
# 2  TRECIS-ITR-H-Types-v4-T1
# 3  TRECIS-ITR-H-Types-v4-T1
# 4  TRECIS-ITR-H-Types-v4-T1
#
#                                          description  \
# 0  TREC-IS Incident Tweet Routing (High-Level) In...
# 1  TREC-IS Incident Tweet Routing (High-Level) In...
# 2  TREC-IS Incident Tweet Routing (High-Level) In...
# 3  TREC-IS Incident Tweet Routing (High-Level) In...
# 4  TREC-IS Incident Tweet Routing (High-Level) In...
#
#                              id  \
# 0          Report-OriginalEvent
# 1               Report-Official
# 2               Report-Official
# 3                   Report-News
# 4  Report-ThirdPartyObservation
#
#                                                 desc       level intentType  \
# 0  A report of the original event occuring. This ...  High-level     Report
# 1  An official report by a government or public s...  High-level     Report
# 2  An official report by a government or public s...  High-level     Report
# 3  The post is a news report providing/linking to...  High-level      Other
# 4  The user is reporting a information that they ...  High-level     Report
#
#                                 exampleLowLevelTypes           eventID  \
# 0                                                 []  fireColorado2012
# 1  ['OfficialStatement', 'RegionalWarning', 'Publ...  fireColorado2012
# 2  ['OfficialStatement', 'RegionalWarning', 'Publ...  fireColorado2012
# 3                    ['NewsHeadline', 'NewsArticle']  fireColorado2012
# 4  ['Group/IndividualMovement', 'PeopleEvacuating...  fireColorado2012
#
#                                    eventName  \
# 0  DEMO: CrisisLex26 2012 Colorado wildfires
# 1  DEMO: CrisisLex26 2012 Colorado wildfires
# 2  DEMO: CrisisLex26 2012 Colorado wildfires
# 3  DEMO: CrisisLex26 2012 Colorado wildfires
# 4  DEMO: CrisisLex26 2012 Colorado wildfires
#
#                                     eventDescription eventType  \
# 0  The 2012 Colorado wildfires were an unusually ...   Unknown
# 1  The 2012 Colorado wildfires were an unusually ...   Unknown
# 2  The 2012 Colorado wildfires were an unusually ...   Unknown
# 3  The 2012 Colorado wildfires were an unusually ...   Unknown
# 4  The 2012 Colorado wildfires were an unusually ...   Unknown
#
#                postID        postCategories postPriority
# 0  211565974422425600  ['ServiceAvailable']         High
# 1  211654415503990784              ['News']       Medium
# 2  211681309368655872              ['News']          Low
# 3  211685621125742592          ['Official']          Low
# 4  211877049147736064           ['Factoid']          Low

# %%
labels = tweets.iloc[:, 10].values
features = tweets.iloc[:, 1].values


features[~np.isfinite(features)] = 0



features[features==np.inf]=np.nan
#features.fillna(features.mean(), inplace=True)

#np.any(np.isnan(features))

features

np.all(np.isfinite(features))
# Out:
# True

# %%
labels
# Out:
# array(['[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Current', 'Forecast']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        '[]', "['Video', 'Images', 'Map']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', '[]', "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', '[]', '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        nan,
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['EvacuateNow', 'GatherAt']", "['NewsHeadline', 'NewsArticle']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['SelfRescue', 'OtherRescue']", "['EvacuateNow', 'GatherAt']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Current', 'Forecast']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['EvacuateNow', 'GatherAt']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['EvacuateNow', 'GatherAt']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PersonsNews', 'MissingPersons', 'EventStatus']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['EvacuateNow', 'GatherAt']", "['Video', 'Images', 'Map']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['EvacuateNow', 'GatherAt']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['UserLocation', 'IncidentLocation']", '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        nan,
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Video', 'Images', 'Map']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['SelfRescue', 'OtherRescue']",
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['EvacuateNow', 'GatherAt']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]',
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Current', 'Forecast']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', '[]', "['NewsHeadline', 'NewsArticle']", '[]', '[]',
#        "['NewsHeadline', 'NewsArticle']",
#        "['NewsHeadline', 'NewsArticle']", '[]', '[]', '[]',
#        "['NewsHeadline', 'NewsArticle']", '[]',
#        "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['NewsHeadline', 'NewsArticle']", '[]', '[]', '[]', '[]',
#        "['NewsHeadline', 'NewsArticle']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        '[]', '[]',
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        '[]',
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', '[]', '[]', '[]', '[]', '[]', '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', "['NewsHeadline', 'NewsArticle']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', '[]', '[]', '[]', '[]', "['NewsHeadline', 'NewsArticle']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        nan,
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', '[]', '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['RegisterNow']", '[]', '[]', '[]',
#        "['NewsHeadline', 'NewsArticle']", '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', '[]', '[]', '[]', "['NewsHeadline', 'NewsArticle']",
#        "['NewsHeadline', 'NewsArticle']", '[]', '[]', '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', "['NewsHeadline', 'NewsArticle']", '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', '[]',
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', '[]', '[]', '[]', '[]', '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', "['Current', 'Forecast']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        nan, '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        nan,
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', "['Current', 'Forecast']", "['Current', 'Forecast']",
#        "['Current', 'Forecast']", "['Current', 'Forecast']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['RegisterNow']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Current', 'Forecast']", '[]', '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', '[]', '[]', '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', '[]', '[]', nan,
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['SelfRescue', 'OtherRescue']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        nan, '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['SelfRescue', 'OtherRescue']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['RegisterNow']", '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        nan,
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]', "['SelfRescue', 'OtherRescue']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', nan, "['SelfRescue', 'OtherRescue']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']", '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', "['NewsHeadline', 'NewsArticle']", '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        nan, '[]', "['NewsHeadline', 'NewsArticle']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']", '[]',
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", nan, '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', "['NewsHeadline', 'NewsArticle']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']", '[]', nan,
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        nan, "['Sadness', 'Hope', 'Support', 'Wellwishing']", '[]',
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['EvacuateNow', 'GatherAt']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', "['SelfRescue', 'OtherRescue']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['Video', 'Images', 'Map']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]', nan,
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['Sadness', 'Hope', 'Support', 'Wellwishing']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['NewsHeadline', 'NewsArticle']", nan, nan,
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]', "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", '[]',
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        "['Video', 'Images', 'Map']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Video', 'Images', 'Map']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", '[]', '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', '[]', "['Current', 'Forecast']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['SelfRescue', 'OtherRescue']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['RegisterNow']", '[]',
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['RegisterNow']", '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['SelfRescue', 'OtherRescue']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['NewsHeadline', 'NewsArticle']", '[]',
# ...
#        '[]',
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Current', 'Forecast']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]', "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        "['Current', 'Forecast']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['BuildingsAtRisk', 'PowerOutage', 'UnexplodedBomb', 'PeopleNotEvacuating', 'FoodShortage', 'InfectiousHumanDisease', 'FuelShortage', 'ContaminatedWaterSupply', 'ContaminatedWater', 'TheftOfAid', 'Looting', 'PriceGouging', 'IDPConcentration', 'WaterShortage', 'SecurityConcern']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['Current', 'Forecast']",
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['NewsHeadline', 'NewsArticle']", "['SelfRescue', 'OtherRescue']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        nan, "['NewsHeadline', 'NewsArticle']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['ExampleOfPreviousEvent', 'LegalInformation', 'HistoricalContext']",
#        "['Current', 'Forecast']", '[]',
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['RegisterNow']", '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['RegisterNow']", '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        '[]',
#        "['LandDevastated', 'InjuriesCount', 'KilledCount', 'NumberDisplacedPeople', 'NumberOfAssailants', 'ShooterCount', 'DamageCost']",
#        '[]',
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Current', 'Forecast']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['Current', 'Forecast']", '[]',
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['SelfRescue', 'OtherRescue']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['UserLocation', 'IncidentLocation']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']", '[]',
#        "['RegisterNow']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['SelfRescue', 'OtherRescue']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['SelfRescue', 'OtherRescue']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['RegisterNow']",
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['PeopleTrapped', 'UnexplodedBombFound', 'UnexplodedBomb', 'IndiscriminateShooting', 'GroupViolence', 'HostageTaken', 'MedicalEmergency']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        '[]',
#        "['HospitalOperating', 'ShelterOffered', 'WaterDistributionPoint', 'FoodDistributionPoint']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        '[]',
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        nan, "['RegisterNow']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['SelfRescue', 'OtherRescue']",
#        "['DonateMoney', 'DonateGoods', 'PromoteFundRaising']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']",
#        "['Group/IndividualMovement', 'PeopleEvacuating', 'DamageObserved', 'CollapsedStructure', 'ExplosionDamage', 'RoadBlocked', 'CompromisedBridge', 'CommunicationLinesDown']",
#        "['OfficialStatement', 'RegionalWarning', 'PublicAlert', 'PressRelease']"],
#       dtype=object)

# %%
import re

features_pp = []
for i in range(0, len(features)):
    feature_pp = re.sub(r'\W', ' ', str(features[i]))
    feature_pp = re.sub(r'\s+[a-zA-Z]\s+', ' ', feature_pp)
    feature_pp = re.sub(r'\^[a-zA-Z]\s+', ' ', feature_pp)
    feature_pp = re.sub(r'\s+', ' ', feature_pp, flags=re.I)
    feature_pp = re.sub(r'^b\s+', '', feature_pp)
    feature_pp = feature_pp.lower()
    features_pp.append(feature_pp)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

vectorizer = TfidfVectorizer(max_features=2500, 
    min_df=7, max_df=0.8, stop_words=stopwords.words('english'))
features_pp = vectorizer.fit_transform(features_pp).toarray()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pseudo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features_pp, labels, test_size=0.2, random_state=0)

# %%
#X_test.fillna(X_test.mean())

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rf = RandomForestClassifier(n_estimators=20, random_state=0)
classifier_rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-12e07af81b3b> in <module>
#       2
#       3 classifier_rf = RandomForestClassifier(n_estimators=20, random_state=0)
# ----> 4 classifier_rf.fit(X_train, y_train)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     803                     estimator=estimator)
#     804     if multi_output:
# --> 805         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#     806                         ensure_2d=False, dtype=None)
#     807     else:
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643
#     644         if force_all_finite:
# --> 645             _assert_all_finite(array,
#     646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     103     elif X.dtype == np.dtype('object') and not allow_nan:
#     104         if _object_dtype_isnan(X).any():
# --> 105             raise ValueError("Input contains NaN")
#     106
#     107
#
# ValueError: Input contains NaN
