# %%
run = "df_int"

# %%
import pandas as pd
import seaborn as sns
from igel import Igel
import numpy as np

# %%
def clean_dataset_char(df):
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df.dropna(inplace=True)
    return df


def clean_dataset_int(df):
    df.fillna(0, inplace=True)
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df.replace(np.nan,0)
    df = df.replace(r'\D+', '', regex=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
    #return df

# %% [markdown]
# ## Overview
#
# Splititng the dataset

# %%
train_df = pd.read_csv("df_int.csv")
score_df = pd.read_csv("before_selection.csv")

#score_df = clean_dataset(score_df)
#train_df = clean_dataset(train_df)

train_df['label'] = '0' #train
score_df['label'] = '1' #score

# %%
score_df
# Out:
#           tweet_id  positive_sentiment  negative_sentiment  numb_of_questions  \
# 0     1.155485e+18                  20                 660                150
# 1     1.155487e+18                  10                 390                520
# 2     1.155488e+18                  20                 630                170
# 3     1.155494e+18                  40                 570                630
# 4     1.155495e+18                 150                 420                400
# ...            ...                 ...                 ...                ...
# 2944  1.158759e+18                  30                 650                 80
# 2945  1.158759e+18                  70                 470                150
# 2946  1.158760e+18                  50                 370                120
# 2947  1.158762e+18                  90                 280                 80
# 2948  1.158763e+18                  30                 190                 90
#
#       tweet_length  userFollowersCount  userFriendsCount  user_list_count  \
# 0              990                 180               420                0
# 1             2570               77090             28140             3920
# 2              980                5370             14860              200
# 3             2570                2950             21450               20
# 4             2170               16820              1040              510
# ...            ...                 ...               ...              ...
# 2944           570                5500              7200               70
# 2945           800                1060              1240                0
# 2946           570                2200               610               30
# 2947           700                 330                 0               40
# 2948           680               15920              5230              940
#
#          dict_precision        dict_recall     dict_f_measure label
# 0     11109999656677246  11109999656677246  11109999656677246     1
# 1                     0                  0                  0     1
# 2                     0                  0                  0     1
# 3                   100  11109999656677246  10529999732971191     1
# 4                     0                  0                  0     1
# ...                 ...                ...                ...   ...
# 2944  14289999961853027  11109999656677246                125     1
# 2945  22219999313354492  22219999313354492  22219999313354492     1
# 2946   3333000183105469  22219999313354492  26670000076293945     1
# 2947  16670000076293945  11109999656677246  13329999923706055     1
# 2948                200  11109999656677246  14289999961853027     1
#
# [2949 rows x 12 columns]

# %%
train_df
# Out:
#          tweet_id  priority  postCategories_x label
# 0    2.115660e+17      0.75              19.0     0
# 1    2.116544e+17      0.50              15.0     0
# 2    2.116813e+17      0.25              15.0     0
# 3    2.116856e+17      0.25              16.0     0
# 4    2.118770e+17      0.25               7.0     0
# ..            ...       ...               ...   ...
# 938  3.963360e+17      0.25              15.0     0
# 939  3.963361e+17      0.25              15.0     0
# 940  3.963362e+17      0.25              15.0     0
# 941  3.963363e+17      0.25               7.0     0
# 942  3.963364e+17      0.25              15.0     0
#
# [943 rows x 4 columns]

# %% [markdown]
# ## Concat

# %%
#concat_df = pd.concat([train_df , score_df])
#concat_df

# %% [markdown]
# ## Create dummies

# %%
#pd.get_dummies

# %%
features_df = pd.get_dummies(data=concat_df, columns=['tweet_id','priority','priority','postCategories_x', 'label',
                                                'positive_sentiment', 'negative_sentiment',
                                                 'numb_of_questions', 'tweet_length', 'userFollowersCount', 'userFriendsCount', 
                                                 'user_list_count', 'dict_precision', 'dict_recall', 'dict_f_measure']
                                                 )

features_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9647e43fa243> in <module>
# ----> 1 features_df = pd.get_dummies(data=concat_df, columns=['tweet_id','priority','priority','postCategories_x', 'label',
#       2                                                 'positive_sentiment', 'negative_sentiment',
#       3                                                  'numb_of_questions', 'tweet_length', 'userFollowersCount', 'userFriendsCount',
#       4                                                  'user_list_count', 'dict_precision', 'dict_recall', 'dict_f_measure']
#       5                                                  )
#
# NameError: name 'concat_df' is not defined

# %%
# Split your data
train_df = features_df[concat_df['label'] == '0']
score_df = features_df[concat_df['label'] == '1']

# Drop your labels
#train_df = train_df.drop('label', axis=0)
#score_df = score_df.drop('label', axis=0)

# %%
#train_df.describe()
#score_df.describe()
train_df

# %%
score_df

# %%
score_df.to_csv(run + "score_df.csv", index=False)
score_df = pd.read_csv(run +"score_df.csv")

# %%
train_df

# %%
#temp
train_df = pd.read_csv(run +"train_df.csv")

# %%
score_df.to_csv("score_df.csv", index=False)
train_df.to_csv("train_df.csv", index=False)

# %%
# stackoverflow.com/questions/44026832/valueerror-number-of-features-of-the-model-must-match-the-input

# %%
# Clean
train_df= clean_dataset_int(train_df)
train_df.head()

# %%
# Clean
score_df= clean_dataset_int(score_df)
score_df.head()

# %%
http://fastml.com/how-to-use-pd-dot-get-dummies-with-the-test-set/

def add_missing_dummy_columns( d, columns ):
    missing_cols = set( columns ) - set( d.columns )
    for c in missing_cols:
        d[c] = 0
        
def fix_columns( d, columns ):  

    add_missing_dummy_columns( d, columns )

    # make sure we have all the columns we need
    assert( set( columns ) - set( d.columns ) == set())

    extra_cols = set( d.columns ) - set( columns )
    if extra_cols:
        print "extra columns:", extra_cols

    d = d[ columns ]
    return d

def fix_columns_test():

    n_cols = 4
    n_rows = 5

    columns = [ "col_{}".format( x ) for x in range( n_cols )]

    # create the "new" set of columns
    new_columns = columns[:]            # copy
    new_columns.pop()
    new_columns.append( 'col_new' ) 

    # create the "new" dataframe
    n = np.random.random(( n_rows, n_cols ))
    d = pd.DataFrame( n, columns = new_columns )

    print d
    print "\n", columns

    fixed_d = fix_columns( d.copy(), columns )
    print "\n", fixed_d

    assert( list( fixed_d.columns ) == columns )
